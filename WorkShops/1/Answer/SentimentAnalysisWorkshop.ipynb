# %% [markdown]
# # Simple Sentiment Analyser

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from nltk.corpus import movie_reviews
from tqdm import tqdm
import nltk
import spacy

# %%
nltk.download('movie_reviews')

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Load IMDB Movie Reviews dataset from NLTK
movie_reviews_data = [(movie_reviews.raw(fileid), category) for category in movie_reviews.categories() for fileid in movie_reviews.fileids(category)]

# Extract texts and labels
texts, labels = zip(*movie_reviews_data)

# Convert labels to binary (0 for negative, 1 for positive)
labels = [0 if label == 'neg' else 1 for label in labels]

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=42)
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.

# %%
# Function to calculate document embeddings using spaCy
def calculate_embeddings(texts):
    embeddings = []
    for text in tqdm(texts):
        doc = nlp(text)
        # Average word vectors to get document vector
        doc_vector = np.mean([word.vector for word in doc if word.has_vector], axis=0)
        embeddings.append(doc_vector)
    return np.array(embeddings)

# Calculate embeddings for training and testing sets
X_train_embeddings = calculate_embeddings(X_train)
X_test_embeddings = calculate_embeddings(X_test)
# Out:
# 100%|██████████| 1600/1600 [03:05<00:00,  8.63it/s]
# 100%|██████████| 400/400 [00:45<00:00,  8.85it/s]

# %%
# Build a pipeline with TruncatedSVD and SVM classifier
# Specify the best n_components hyperparameter.

# create a array to save accuracies for different numbers
components_array_accuracy = []

for num in range(10 , 97):
    model = make_pipeline(TruncatedSVD(n_components=num), SVC())

    # Fit the model on training data
    model.fit(X_train_embeddings, y_train)

    # Make predictions on test data
    predictions = model.predict(X_test_embeddings)

    # Evaluate the accuracy
    accuracy = accuracy_score(y_test, predictions)
    components_array_accuracy.append((num , accuracy))
    print(f"n_components={num}  =>  Accuracy: {accuracy}")
# Out:
# n_components=10  =>  Accuracy: 0.6475
# n_components=11  =>  Accuracy: 0.6525
# n_components=12  =>  Accuracy: 0.6575
# n_components=13  =>  Accuracy: 0.6625
# n_components=14  =>  Accuracy: 0.65
# n_components=15  =>  Accuracy: 0.65
# n_components=16  =>  Accuracy: 0.6625
# n_components=17  =>  Accuracy: 0.655
# n_components=18  =>  Accuracy: 0.65
# n_components=19  =>  Accuracy: 0.66
# n_components=20  =>  Accuracy: 0.66
# n_components=21  =>  Accuracy: 0.655
# n_components=22  =>  Accuracy: 0.6575
# n_components=23  =>  Accuracy: 0.6625
# n_components=24  =>  Accuracy: 0.665
# n_components=25  =>  Accuracy: 0.6675
# n_components=26  =>  Accuracy: 0.6675
# n_components=27  =>  Accuracy: 0.6675
# n_components=28  =>  Accuracy: 0.6675
# n_components=29  =>  Accuracy: 0.675
# n_components=30  =>  Accuracy: 0.6825
# n_components=31  =>  Accuracy: 0.685
# n_components=32  =>  Accuracy: 0.68
# n_components=33  =>  Accuracy: 0.685
# n_components=34  =>  Accuracy: 0.68
# n_components=35  =>  Accuracy: 0.67
# n_components=36  =>  Accuracy: 0.6775
# n_components=37  =>  Accuracy: 0.6775
# n_components=38  =>  Accuracy: 0.6775
# n_components=39  =>  Accuracy: 0.675
# n_components=40  =>  Accuracy: 0.6875
# n_components=41  =>  Accuracy: 0.68
# n_components=42  =>  Accuracy: 0.6825
# n_components=43  =>  Accuracy: 0.6775
# n_components=44  =>  Accuracy: 0.6725
# n_components=45  =>  Accuracy: 0.675
# n_components=46  =>  Accuracy: 0.6725
# n_components=47  =>  Accuracy: 0.68
# n_components=48  =>  Accuracy: 0.6825
# n_components=49  =>  Accuracy: 0.6775
# n_components=50  =>  Accuracy: 0.6775
# n_components=51  =>  Accuracy: 0.6925
# n_components=52  =>  Accuracy: 0.69
# n_components=53  =>  Accuracy: 0.6825
# n_components=54  =>  Accuracy: 0.6775
# n_components=55  =>  Accuracy: 0.6775
# n_components=56  =>  Accuracy: 0.685
# n_components=57  =>  Accuracy: 0.6875
# n_components=58  =>  Accuracy: 0.68
# n_components=59  =>  Accuracy: 0.6825
# n_components=60  =>  Accuracy: 0.685
# n_components=61  =>  Accuracy: 0.685
# n_components=62  =>  Accuracy: 0.6875
# n_components=63  =>  Accuracy: 0.685
# n_components=64  =>  Accuracy: 0.6875
# n_components=65  =>  Accuracy: 0.6875
# n_components=66  =>  Accuracy: 0.685
# n_components=67  =>  Accuracy: 0.6875
# n_components=68  =>  Accuracy: 0.69
# n_components=69  =>  Accuracy: 0.695
# n_components=70  =>  Accuracy: 0.6925
# n_components=71  =>  Accuracy: 0.6925
# n_components=72  =>  Accuracy: 0.7
# n_components=73  =>  Accuracy: 0.6975
# n_components=74  =>  Accuracy: 0.695
# n_components=75  =>  Accuracy: 0.6925
# n_components=76  =>  Accuracy: 0.7
# n_components=77  =>  Accuracy: 0.6975
# n_components=78  =>  Accuracy: 0.6875
# n_components=79  =>  Accuracy: 0.6925
# n_components=80  =>  Accuracy: 0.6925
# n_components=81  =>  Accuracy: 0.69
# n_components=82  =>  Accuracy: 0.69
# n_components=83  =>  Accuracy: 0.69
# n_components=84  =>  Accuracy: 0.6925
# n_components=85  =>  Accuracy: 0.695
# n_components=86  =>  Accuracy: 0.695
# n_components=87  =>  Accuracy: 0.69
# n_components=88  =>  Accuracy: 0.6875
# n_components=89  =>  Accuracy: 0.6875
# n_components=90  =>  Accuracy: 0.6925
# n_components=91  =>  Accuracy: 0.6925
# n_components=92  =>  Accuracy: 0.695
# n_components=93  =>  Accuracy: 0.6925
# n_components=94  =>  Accuracy: 0.6925
# n_components=95  =>  Accuracy: 0.6925
# n_components=96  =>  Accuracy: 0.6925

# %%
# Find maximum index of accuracy List
inx = np.argmax([max_inx[1] for max_inx in components_array_accuracy])
the_best_index_of_component , max_accuracy = components_array_accuracy[inx]
print(f"the_best_index_of_component: {the_best_index_of_component} => Maximum_Accuracy: {max_accuracy}")
# Out:
# the_best_index_of_component: 72 => Maximum_Accuracy: 0.7

# %% [markdown]
# #More accurate one

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from nltk.corpus import movie_reviews
from transformers import AutoTokenizer, AutoModel
import torch

# %%
# Load BERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
bert_model = AutoModel.from_pretrained("bert-base-uncased")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
def calculate_embeddings(texts):
    embeddings = []
    for text in tqdm(texts):
        # Tokenize the text
        tokens = tokenizer(text, return_tensors="pt", truncation=True, padding=True)

        # Get BERT model output
        with torch.no_grad():
            model_output = bert_model(**tokens)

        # Use mean pooling to get sentence embeddings
        doc_vector = np.mean(model_output['last_hidden_state'].numpy(), axis=1)
        doc_vector = np.squeeze(doc_vector, axis=0)
        embeddings.append(doc_vector)

    return np.array(embeddings)


# Calculate embeddings for training and testing sets
X_train_embeddings = calculate_embeddings(X_train)
X_test_embeddings = calculate_embeddings(X_test)

print(f"X_train_embeddings= {X_train_embeddings.shape} , X_test_embeddings= {X_test_embeddings.shape}")
# Out:
# 100%|██████████| 1600/1600 [48:15<00:00,  1.81s/it]
# 100%|██████████| 400/400 [10:46<00:00,  1.62s/it]
# X_train_embeddings= (1600, 768) , X_test_embeddings= (400, 768)

# %%
# Build a pipeline with TruncatedSVD and SVM classifier
# Specify the best n_components hyperparameter.

# create a array to save accuracies for different the amount of n_components
bert_accuracy = []

for num in range(10 , 257):
    model = make_pipeline(TruncatedSVD(n_components=num), SVC())

    # Fit the model on training data
    model.fit(X_train_embeddings, y_train)

    # Make predictions on test data
    predictions = model.predict(X_test_embeddings)

    # Evaluate the accuracy
    accuracy = accuracy_score(y_test, predictions)
    bert_accuracy.append((num , accuracy))
    print(f"n_components= {num}  =>  Accuracy: {accuracy}")
# Out:
# n_components= 10  =>  Accuracy: 0.6475
# n_components= 11  =>  Accuracy: 0.64
# n_components= 12  =>  Accuracy: 0.655
# n_components= 13  =>  Accuracy: 0.645
# n_components= 14  =>  Accuracy: 0.645
# n_components= 15  =>  Accuracy: 0.6525
# n_components= 16  =>  Accuracy: 0.665
# n_components= 17  =>  Accuracy: 0.6625
# n_components= 18  =>  Accuracy: 0.6775
# n_components= 19  =>  Accuracy: 0.68
# n_components= 20  =>  Accuracy: 0.6925
# n_components= 21  =>  Accuracy: 0.7075
# n_components= 22  =>  Accuracy: 0.72
# n_components= 23  =>  Accuracy: 0.725
# n_components= 24  =>  Accuracy: 0.7375
# n_components= 25  =>  Accuracy: 0.7325
# n_components= 26  =>  Accuracy: 0.7475
# n_components= 27  =>  Accuracy: 0.745
# n_components= 28  =>  Accuracy: 0.7425
# n_components= 29  =>  Accuracy: 0.77
# n_components= 30  =>  Accuracy: 0.765
# n_components= 31  =>  Accuracy: 0.7675
# n_components= 32  =>  Accuracy: 0.765
# n_components= 33  =>  Accuracy: 0.765
# n_components= 34  =>  Accuracy: 0.76
# n_components= 35  =>  Accuracy: 0.7725
# n_components= 36  =>  Accuracy: 0.765
# n_components= 37  =>  Accuracy: 0.78
# n_components= 38  =>  Accuracy: 0.775
# n_components= 39  =>  Accuracy: 0.775
# n_components= 40  =>  Accuracy: 0.785
# n_components= 41  =>  Accuracy: 0.785
# n_components= 42  =>  Accuracy: 0.7875
# n_components= 43  =>  Accuracy: 0.785
# n_components= 44  =>  Accuracy: 0.7875
# n_components= 45  =>  Accuracy: 0.7875
# n_components= 46  =>  Accuracy: 0.7875
# n_components= 47  =>  Accuracy: 0.7825
# n_components= 48  =>  Accuracy: 0.7875
# n_components= 49  =>  Accuracy: 0.78
# n_components= 50  =>  Accuracy: 0.785
# n_components= 51  =>  Accuracy: 0.785
# n_components= 52  =>  Accuracy: 0.785
# n_components= 53  =>  Accuracy: 0.785
# n_components= 54  =>  Accuracy: 0.7825
# n_components= 55  =>  Accuracy: 0.7875
# n_components= 56  =>  Accuracy: 0.7925
# n_components= 57  =>  Accuracy: 0.78
# n_components= 58  =>  Accuracy: 0.785
# n_components= 59  =>  Accuracy: 0.7875
# n_components= 60  =>  Accuracy: 0.7875
# n_components= 61  =>  Accuracy: 0.7875
# n_components= 62  =>  Accuracy: 0.7875
# n_components= 63  =>  Accuracy: 0.7875
# n_components= 64  =>  Accuracy: 0.785
# n_components= 65  =>  Accuracy: 0.79
# n_components= 66  =>  Accuracy: 0.79
# n_components= 67  =>  Accuracy: 0.79
# n_components= 68  =>  Accuracy: 0.79
# n_components= 69  =>  Accuracy: 0.79
# n_components= 70  =>  Accuracy: 0.7875
# n_components= 71  =>  Accuracy: 0.79
# n_components= 72  =>  Accuracy: 0.785
# n_components= 73  =>  Accuracy: 0.7875
# n_components= 74  =>  Accuracy: 0.7875
# n_components= 75  =>  Accuracy: 0.7925
# n_components= 76  =>  Accuracy: 0.7875
# n_components= 77  =>  Accuracy: 0.79
# n_components= 78  =>  Accuracy: 0.7975
# n_components= 79  =>  Accuracy: 0.8
# n_components= 80  =>  Accuracy: 0.8
# n_components= 81  =>  Accuracy: 0.805
# n_components= 82  =>  Accuracy: 0.8
# n_components= 83  =>  Accuracy: 0.8
# n_components= 84  =>  Accuracy: 0.8
# n_components= 85  =>  Accuracy: 0.795
# n_components= 86  =>  Accuracy: 0.8
# n_components= 87  =>  Accuracy: 0.8075
# n_components= 88  =>  Accuracy: 0.8
# n_components= 89  =>  Accuracy: 0.805
# n_components= 90  =>  Accuracy: 0.8025
# n_components= 91  =>  Accuracy: 0.7975
# n_components= 92  =>  Accuracy: 0.8
# n_components= 93  =>  Accuracy: 0.8
# n_components= 94  =>  Accuracy: 0.805
# n_components= 95  =>  Accuracy: 0.8075
# n_components= 96  =>  Accuracy: 0.7975
# n_components= 97  =>  Accuracy: 0.8075
# n_components= 98  =>  Accuracy: 0.8025
# n_components= 99  =>  Accuracy: 0.8025
# n_components= 100  =>  Accuracy: 0.795
# n_components= 101  =>  Accuracy: 0.8025
# n_components= 102  =>  Accuracy: 0.7975
# n_components= 103  =>  Accuracy: 0.7975
# n_components= 104  =>  Accuracy: 0.7975
# n_components= 105  =>  Accuracy: 0.795
# n_components= 106  =>  Accuracy: 0.805
# n_components= 107  =>  Accuracy: 0.7925
# n_components= 108  =>  Accuracy: 0.7975
# n_components= 109  =>  Accuracy: 0.7975
# n_components= 110  =>  Accuracy: 0.7975
# n_components= 111  =>  Accuracy: 0.79
# n_components= 112  =>  Accuracy: 0.795
# n_components= 113  =>  Accuracy: 0.8025
# n_components= 114  =>  Accuracy: 0.8025
# n_components= 115  =>  Accuracy: 0.8
# n_components= 116  =>  Accuracy: 0.8025
# n_components= 117  =>  Accuracy: 0.8025
# n_components= 118  =>  Accuracy: 0.8
# n_components= 119  =>  Accuracy: 0.8
# n_components= 120  =>  Accuracy: 0.7975
# n_components= 121  =>  Accuracy: 0.8025
# n_components= 122  =>  Accuracy: 0.7975
# n_components= 123  =>  Accuracy: 0.8
# n_components= 124  =>  Accuracy: 0.795
# n_components= 125  =>  Accuracy: 0.8025
# n_components= 126  =>  Accuracy: 0.8025
# n_components= 127  =>  Accuracy: 0.8
# n_components= 128  =>  Accuracy: 0.7975
# n_components= 129  =>  Accuracy: 0.8025
# n_components= 130  =>  Accuracy: 0.8
# n_components= 131  =>  Accuracy: 0.8
# n_components= 132  =>  Accuracy: 0.795
# n_components= 133  =>  Accuracy: 0.7975
# n_components= 134  =>  Accuracy: 0.7975
# n_components= 135  =>  Accuracy: 0.8
# n_components= 136  =>  Accuracy: 0.7975
# n_components= 137  =>  Accuracy: 0.7925
# n_components= 138  =>  Accuracy: 0.7975
# n_components= 139  =>  Accuracy: 0.7975
# n_components= 140  =>  Accuracy: 0.8025
# n_components= 141  =>  Accuracy: 0.7975
# n_components= 142  =>  Accuracy: 0.7975
# n_components= 143  =>  Accuracy: 0.8
# n_components= 144  =>  Accuracy: 0.795
# n_components= 145  =>  Accuracy: 0.7975
# n_components= 146  =>  Accuracy: 0.7975
# n_components= 147  =>  Accuracy: 0.8025
# n_components= 148  =>  Accuracy: 0.795
# n_components= 149  =>  Accuracy: 0.795
# n_components= 150  =>  Accuracy: 0.7925
# n_components= 151  =>  Accuracy: 0.8
# n_components= 152  =>  Accuracy: 0.8
# n_components= 153  =>  Accuracy: 0.7925
# n_components= 154  =>  Accuracy: 0.795
# n_components= 155  =>  Accuracy: 0.7975
# n_components= 156  =>  Accuracy: 0.7975
# n_components= 157  =>  Accuracy: 0.7975
# n_components= 158  =>  Accuracy: 0.7975
# n_components= 159  =>  Accuracy: 0.7975
# n_components= 160  =>  Accuracy: 0.795
# n_components= 161  =>  Accuracy: 0.7975
# n_components= 162  =>  Accuracy: 0.7975
# n_components= 163  =>  Accuracy: 0.795
# n_components= 164  =>  Accuracy: 0.7925
# n_components= 165  =>  Accuracy: 0.795
# n_components= 166  =>  Accuracy: 0.795
# n_components= 167  =>  Accuracy: 0.7975
# n_components= 168  =>  Accuracy: 0.795
# n_components= 169  =>  Accuracy: 0.7925
# n_components= 170  =>  Accuracy: 0.795
# n_components= 171  =>  Accuracy: 0.7975
# n_components= 172  =>  Accuracy: 0.8
# n_components= 173  =>  Accuracy: 0.795
# n_components= 174  =>  Accuracy: 0.7925
# n_components= 175  =>  Accuracy: 0.7975
# n_components= 176  =>  Accuracy: 0.795
# n_components= 177  =>  Accuracy: 0.795
# n_components= 178  =>  Accuracy: 0.795
# n_components= 179  =>  Accuracy: 0.795
# n_components= 180  =>  Accuracy: 0.795
# n_components= 181  =>  Accuracy: 0.7975
# n_components= 182  =>  Accuracy: 0.7925
# n_components= 183  =>  Accuracy: 0.795
# n_components= 184  =>  Accuracy: 0.795
# n_components= 185  =>  Accuracy: 0.795
# n_components= 186  =>  Accuracy: 0.7975
# n_components= 187  =>  Accuracy: 0.795
# n_components= 188  =>  Accuracy: 0.795
# n_components= 189  =>  Accuracy: 0.7975
# n_components= 190  =>  Accuracy: 0.8025
# n_components= 191  =>  Accuracy: 0.795
# n_components= 192  =>  Accuracy: 0.795
# n_components= 193  =>  Accuracy: 0.795
# n_components= 194  =>  Accuracy: 0.7925
# n_components= 195  =>  Accuracy: 0.7925
# n_components= 196  =>  Accuracy: 0.79
# n_components= 197  =>  Accuracy: 0.7975
# n_components= 198  =>  Accuracy: 0.79
# n_components= 199  =>  Accuracy: 0.795
# n_components= 200  =>  Accuracy: 0.795
# n_components= 201  =>  Accuracy: 0.795
# n_components= 202  =>  Accuracy: 0.7975
# n_components= 203  =>  Accuracy: 0.795
# n_components= 204  =>  Accuracy: 0.7925
# n_components= 205  =>  Accuracy: 0.79
# n_components= 206  =>  Accuracy: 0.79
# n_components= 207  =>  Accuracy: 0.795
# n_components= 208  =>  Accuracy: 0.795
# n_components= 209  =>  Accuracy: 0.7975
# n_components= 210  =>  Accuracy: 0.7925
# n_components= 211  =>  Accuracy: 0.7925
# n_components= 212  =>  Accuracy: 0.7925
# n_components= 213  =>  Accuracy: 0.7925
# n_components= 214  =>  Accuracy: 0.795
# n_components= 215  =>  Accuracy: 0.7925
# n_components= 216  =>  Accuracy: 0.7925
# n_components= 217  =>  Accuracy: 0.7925
# n_components= 218  =>  Accuracy: 0.7925
# n_components= 219  =>  Accuracy: 0.795
# n_components= 220  =>  Accuracy: 0.7925
# n_components= 221  =>  Accuracy: 0.7975
# n_components= 222  =>  Accuracy: 0.795
# n_components= 223  =>  Accuracy: 0.7975
# n_components= 224  =>  Accuracy: 0.7925
# n_components= 225  =>  Accuracy: 0.7925
# n_components= 226  =>  Accuracy: 0.7925
# n_components= 227  =>  Accuracy: 0.7925
# n_components= 228  =>  Accuracy: 0.795
# n_components= 229  =>  Accuracy: 0.7925
# n_components= 230  =>  Accuracy: 0.79
# n_components= 231  =>  Accuracy: 0.7975
# n_components= 232  =>  Accuracy: 0.795
# n_components= 233  =>  Accuracy: 0.7975
# n_components= 234  =>  Accuracy: 0.79
# n_components= 235  =>  Accuracy: 0.7925
# n_components= 236  =>  Accuracy: 0.7925
# n_components= 237  =>  Accuracy: 0.8
# n_components= 238  =>  Accuracy: 0.7925
# n_components= 239  =>  Accuracy: 0.7925
# n_components= 240  =>  Accuracy: 0.79
# n_components= 241  =>  Accuracy: 0.7925
# n_components= 242  =>  Accuracy: 0.7975
# n_components= 243  =>  Accuracy: 0.79
# n_components= 244  =>  Accuracy: 0.795
# n_components= 245  =>  Accuracy: 0.7925
# n_components= 246  =>  Accuracy: 0.7975
# n_components= 247  =>  Accuracy: 0.795
# n_components= 248  =>  Accuracy: 0.7925
# n_components= 249  =>  Accuracy: 0.7925
# n_components= 250  =>  Accuracy: 0.7975
# n_components= 251  =>  Accuracy: 0.795
# n_components= 252  =>  Accuracy: 0.7975
# n_components= 253  =>  Accuracy: 0.795
# n_components= 254  =>  Accuracy: 0.795
# n_components= 255  =>  Accuracy: 0.7975
# n_components= 256  =>  Accuracy: 0.795

# %%
# Find maximum index of accuracy List
inx = np.argmax([max_inx[1] for max_inx in bert_accuracy])
the_best_index_of_component , max_accuracy = bert_accuracy[inx]

print(f"the_best_index_of_component: {the_best_index_of_component} => Maximum_Accuracy: {max_accuracy}")
# Out:
# the_best_index_of_component: 87 => Maximum_Accuracy: 0.8075
