# %%
# !wget https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip && unzip v2_Annotations_Train_mscoco && \
wget https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip && unzip v2_Questions_Train_mscoco
# Out:
# --2024-04-08 04:37:11--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.230.8, 52.216.52.40, 54.231.224.0, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.230.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21708861 (21M) [application/zip]
# Saving to: ‘v2_Annotations_Train_mscoco.zip’
#
# v2_Annotations_Trai 100%[===================>]  20.70M  49.7MB/s    in 0.4s
#
# 2024-04-08 04:37:12 (49.7 MB/s) - ‘v2_Annotations_Train_mscoco.zip’ saved [21708861/21708861]
#
# Archive:  v2_Annotations_Train_mscoco.zip
#   inflating: v2_mscoco_train2014_annotations.json
# --2024-04-08 04:37:16--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.203.128, 54.231.136.32, 52.217.174.64, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7239401 (6.9M) [application/zip]
# Saving to: ‘v2_Questions_Train_mscoco.zip’
#
# v2_Questions_Train_ 100%[===================>]   6.90M  34.1MB/s    in 0.2s
#
# 2024-04-08 04:37:16 (34.1 MB/s) - ‘v2_Questions_Train_mscoco.zip’ saved [7239401/7239401]
#
# Archive:  v2_Questions_Train_mscoco.zip
#   inflating: v2_OpenEnded_mscoco_train2014_questions.json

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
import os
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import json
import copy
import glob
import torch
import random
import operator
import numpy as np
import urllib.request
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from google.colab import files
from numpy.random import choice
from sklearn.manifold import TSNE
from collections import Counter, defaultdict
import pandas as pd
import csv
from torch.utils.data import Dataset
from torchvision.transforms import *
from tqdm.notebook import tqdm
import pickle
from transformers import DistilBertTokenizer, DistilBertModel, DistilBertForSequenceClassification
import cv2
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.models as models

# %%
annotations = json.load(open("v2_mscoco_train2014_annotations.json"))
questions = json.load(open("v2_OpenEnded_mscoco_train2014_questions.json"))

# %%
annotations.keys()
# Out:
# dict_keys(['info', 'license', 'data_subtype', 'annotations', 'data_type'])

# %%
annotations['annotations'][0]
# Out:
# {'question_type': 'what is this',
#  'multiple_choice_answer': 'net',
#  'answers': [{'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3},
#   {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6},
#   {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}],
#  'image_id': 458752,
#  'answer_type': 'other',
#  'question_id': 458752000}

# %%
questions.keys()
# Out:
# dict_keys(['info', 'task_type', 'data_type', 'license', 'data_subtype', 'questions'])

# %%
questions['questions']
# Out:
# [{'image_id': 458752,
#   'question': 'What is this photo taken looking through?',
#   'question_id': 458752000},
#  {'image_id': 458752,
#   'question': 'What position is this man playing?',
#   'question_id': 458752001},
#  {'image_id': 458752,
#   'question': 'What color is the players shirt?',
#   'question_id': 458752002},
#  {'image_id': 458752,
#   'question': 'Is this man a professional baseball player?',
#   'question_id': 458752003},
#  {'image_id': 262146,
#   'question': 'What color is the snow?',
#   'question_id': 262146000},
#  {'image_id': 262146,
#   'question': 'What is the person doing?',
#   'question_id': 262146001},
#  {'image_id': 262146,
#   'question': 'What color is the persons headwear?',
#   'question_id': 262146002},
#  {'image_id': 524291,
#   'question': "What is in the person's hand?",
#   'question_id': 524291000},
#  {'image_id': 524291,
#   'question': 'Is the dog waiting?',
#   'question_id': 524291001},
#  {'image_id': 524291,
#   'question': 'Is the dog looking at a tennis ball or frisbee?',
#   'question_id': 524291002},
#  {'image_id': 393221,
#   'question': 'Is the sky blue?',
#   'question_id': 393221000},
#  {'image_id': 393221,
#   'question': 'Is there snow on the mountains?',
#   'question_id': 393221001},
#  {'image_id': 393221,
#   'question': 'What is the white streak?',
#   'question_id': 393221002},
#  {'image_id': 393223,
#   'question': 'Is the window open?',
#   'question_id': 393223000},
#  {'image_id': 393223,
#   'question': 'What color is the toothbrush?',
#   'question_id': 393223001},
#  {'image_id': 393223,
#   'question': 'What is the child doing?',
#   'question_id': 393223002},
#  {'image_id': 393223,
#   'question': 'Is she brushing?',
#   'question_id': 393223003},
#  {'image_id': 393224,
#   'question': 'Is the man smiling?',
#   'question_id': 393224000},
#  {'image_id': 393224,
#   'question': 'What is the business man doing in the picture?',
#   'question_id': 393224001},
#  {'image_id': 393224,
#   'question': 'Does his tie pair well with his suit?',
#   'question_id': 393224002},
#  {'image_id': 393224,
#   'question': 'Does the man look happy?',
#   'question_id': 393224003},
#  {'image_id': 393224,
#   'question': 'Is this photo in color?',
#   'question_id': 393224004},
#  {'image_id': 393224,
#   'question': 'Is the man wearing a plain tie?',
#   'question_id': 393224005},
#  {'image_id': 524297,
#   'question': 'Judging from the dress, was this taken in a Latin American country?',
#   'question_id': 524297000},
#  {'image_id': 524297,
#   'question': 'What colors are shown in this picture?',
#   'question_id': 524297001},
#  {'image_id': 524297,
#   'question': 'Are the men on the sidewalk?',
#   'question_id': 524297002},
#  {'image_id': 524297,
#   'question': 'Was this photo taken recently?',
#   'question_id': 524297003},
#  {'image_id': 393227,
#   'question': 'Does the guy have a tattoo?',
#   'question_id': 393227000},
#  {'image_id': 393227,
#   'question': 'What is this man riding on?',
#   'question_id': 393227001},
#  {'image_id': 393227,
#   'question': "How many tattoos can be seen on this man's body?",
#   'question_id': 393227002},
#  {'image_id': 393227,
#   'question': 'What color is his hat?',
#   'question_id': 393227003},
#  {'image_id': 393227,
#   'question': "Is the man's visor providing his face enough protection?",
#   'question_id': 393227004},
#  {'image_id': 131084,
#   'question': 'What color is the jacket?',
#   'question_id': 131084000},
#  {'image_id': 131084,
#   'question': 'Is the man riding on a dirt path?',
#   'question_id': 131084001},
#  {'image_id': 131084,
#   'question': 'What is the man riding on?',
#   'question_id': 131084002},
#  {'image_id': 131074,
#   'question': 'What is on the pillow?',
#   'question_id': 131074000},
#  {'image_id': 131074,
#   'question': 'How many pieces of furniture which are used for sleeping are featured in this picture?',
#   'question_id': 131074001},
#  {'image_id': 131074,
#   'question': 'Are the walls done in a summery color?',
#   'question_id': 131074002},
#  {'image_id': 131074,
#   'question': 'Is the curtain patterned?',
#   'question_id': 131074003},
#  {'image_id': 131074,
#   'question': 'What is sitting on the bench?',
#   'question_id': 131074004},
#  {'image_id': 131074,
#   'question': 'Are the windows the same size?',
#   'question_id': 131074005},
#  {'image_id': 393230,
#   'question': 'What is this person doing?',
#   'question_id': 393230000},
#  {'image_id': 393230,
#   'question': 'How many people are in this image?',
#   'question_id': 393230001},
#  {'image_id': 393230,
#   'question': 'Is there a shadow of a tree in the foreground?',
#   'question_id': 393230002},
#  {'image_id': 393230,
#   'question': 'What is the man doing?',
#   'question_id': 393230003},
#  {'image_id': 393230,
#   'question': 'What color is the sky?',
#   'question_id': 393230004},
#  {'image_id': 393230,
#   'question': 'What is the person wearing?',
#   'question_id': 393230005},
#  {'image_id': 393230,
#   'question': 'Did someone forget his luggage in the snow?',
#   'question_id': 393230006},
#  {'image_id': 393230,
#   'question': 'What color is his coat?',
#   'question_id': 393230007},
#  {'image_id': 393230, 'question': 'Is it daytime?', 'question_id': 393230008},
#  {'image_id': 393230,
#   'question': 'What is she holding?',
#   'question_id': 393230009},
#  {'image_id': 393230,
#   'question': 'Is the person wearing a hat?',
#   'question_id': 393230010},
#  {'image_id': 131087,
#   'question': 'What is the dog riding on?',
#   'question_id': 131087000},
#  {'image_id': 131087,
#   'question': 'Is the dog wearing a collar?',
#   'question_id': 131087001},
#  {'image_id': 131087,
#   'question': 'Is it a clear day?',
#   'question_id': 131087002},
#  {'image_id': 131087,
#   'question': 'Is there a body of water here?',
#   'question_id': 131087003},
#  {'image_id': 131087,
#   'question': 'What is in the water?',
#   'question_id': 131087004},
#  {'image_id': 131075,
#   'question': 'What does the green light, on the TV, indicate?',
#   'question_id': 131075000},
#  {'image_id': 131075,
#   'question': 'Is the light on?',
#   'question_id': 131075001},
#  {'image_id': 131075,
#   'question': 'What room of the house is this?',
#   'question_id': 131075002},
#  {'image_id': 131075,
#   'question': 'What is the size of the TV?',
#   'question_id': 131075003},
#  {'image_id': 131075,
#   'question': 'Is the room messy?',
#   'question_id': 131075004},
#  {'image_id': 131075,
#   'question': 'Is this a TV screen?',
#   'question_id': 131075005},
#  {'image_id': 131075,
#   'question': 'How big is the TV?',
#   'question_id': 131075006},
#  {'image_id': 131075,
#   'question': 'What companion object to the TV can be seen in the bottom right of the picture?',
#   'question_id': 131075007},
#  {'image_id': 131075,
#   'question': 'What is the small computer on the left called?',
#   'question_id': 131075008},
#  {'image_id': 131075,
#   'question': 'What is above the TV?',
#   'question_id': 131075009},
#  {'image_id': 131075,
#   'question': 'What is on the display?',
#   'question_id': 131075010},
#  {'image_id': 131075,
#   'question': 'Is there a laptop in the image?',
#   'question_id': 131075011},
#  {'image_id': 131075,
#   'question': 'Is it a monitor or a screen projection?',
#   'question_id': 131075012},
#  {'image_id': 131075,
#   'question': 'What is on the TV screen?',
#   'question_id': 131075013},
#  {'image_id': 131075,
#   'question': 'What is the title of the presentation in the picture?',
#   'question_id': 131075014},
#  {'image_id': 137045,
#   'question': 'What color is the bear?',
#   'question_id': 137045000},
#  {'image_id': 137045,
#   'question': 'Is the animal a mammal?',
#   'question_id': 137045001},
#  {'image_id': 137045, 'question': 'What is this?', 'question_id': 137045002},
#  {'image_id': 131093,
#   'question': 'Are there rocks in the picture?',
#   'question_id': 131093000},
#  {'image_id': 131093,
#   'question': 'Has the sheep recently been shaved?',
#   'question_id': 131093001},
#  {'image_id': 131093,
#   'question': 'How many sheeps are this?',
#   'question_id': 131093002},
#  {'image_id': 131093,
#   'question': 'Are there three sheep?',
#   'question_id': 131093003},
#  {'image_id': 524311,
#   'question': 'What is the man playing?',
#   'question_id': 524311000},
#  {'image_id': 524311,
#   'question': 'Is the man having a good time?',
#   'question_id': 524311001},
#  {'image_id': 524311,
#   'question': 'What does the man have on his face?',
#   'question_id': 524311002},
#  {'image_id': 25,
#   'question': 'What is in front of the giraffes?',
#   'question_id': 25000},
#  {'image_id': 25,
#   'question': 'What do these giraffes have in common?',
#   'question_id': 25001},
#  {'image_id': 25,
#   'question': 'Could this photo be from a zoo?',
#   'question_id': 25002},
#  {'image_id': 25, 'question': 'Are the animals eating?', 'question_id': 25003},
#  {'image_id': 25, 'question': 'Where is the giraffe?', 'question_id': 25004},
#  {'image_id': 25, 'question': 'Is there a zebra?', 'question_id': 25005},
#  {'image_id': 25,
#   'question': 'What is the giraffe standing behind?',
#   'question_id': 25006},
#  {'image_id': 25,
#   'question': 'Is the giraffe eating the tree?',
#   'question_id': 25007},
#  {'image_id': 25,
#   'question': 'Are both giraffes standing?',
#   'question_id': 25008},
#  {'image_id': 25, 'question': 'Are they at a zoo?', 'question_id': 25009},
#  {'image_id': 25,
#   'question': 'What is on the ground next to the giraffe on the right?',
#   'question_id': 25010},
#  {'image_id': 25,
#   'question': 'Are some of the trees dead?',
#   'question_id': 25011},
#  {'image_id': 25,
#   'question': 'Are any of the animals eating?',
#   'question_id': 25012},
#  {'image_id': 25,
#   'question': 'Is the giraffe in the shade?',
#   'question_id': 25013},
#  {'image_id': 25,
#   'question': 'Are these giraffes living free range?',
#   'question_id': 25014},
#  {'image_id': 25,
#   'question': 'How many giraffes are there?',
#   'question_id': 25015},
#  {'image_id': 25,
#   'question': 'Is there a rock near the giraffe?',
#   'question_id': 25016},
#  {'image_id': 25,
#   'question': 'How many animals are in this photo?',
#   'question_id': 25017},
#  {'image_id': 524314,
#   'question': 'Why is the man on the street?',
#   'question_id': 524314000},
#  {'image_id': 524314,
#   'question': 'How is the man sitting?',
#   'question_id': 524314001},
#  {'image_id': 524314,
#   'question': 'What does the word in the upper-left corner, behind the window, translate to in English?',
#   'question_id': 524314002},
#  {'image_id': 262171,
#   'question': 'How many people are on the boat?',
#   'question_id': 262171000},
#  {'image_id': 262171,
#   'question': 'What color are the leaves?',
#   'question_id': 262171001},
#  {'image_id': 262171,
#   'question': 'What type of watercraft is that?',
#   'question_id': 262171002},
#  {'image_id': 262172,
#   'question': 'Where are the two blue coolers?',
#   'question_id': 262172000},
#  {'image_id': 262172,
#   'question': 'What kind of room is this?',
#   'question_id': 262172001},
#  {'image_id': 262172,
#   'question': 'Are they moving?',
#   'question_id': 262172002},
#  {'image_id': 131101,
#   'question': 'What color is the umbrella?',
#   'question_id': 131101000},
#  {'image_id': 131101,
#   'question': 'Is this man angry?',
#   'question_id': 131101001},
#  {'image_id': 131101,
#   'question': 'Which hand holds the umbrella?',
#   'question_id': 131101002},
#  {'image_id': 30,
#   'question': 'Are there flowers in the vase?',
#   'question_id': 30000},
#  {'image_id': 30,
#   'question': 'What is the vase sitting on?',
#   'question_id': 30001},
#  {'image_id': 30,
#   'question': 'Is the sun to the right or left of this flower?',
#   'question_id': 30002},
#  {'image_id': 30, 'question': 'Are the flowers open?', 'question_id': 30003},
#  {'image_id': 30, 'question': 'What color is the vase?', 'question_id': 30004},
#  {'image_id': 30,
#   'question': 'Are all the flowers white?',
#   'question_id': 30005},
#  {'image_id': 524320,
#   'question': 'Is the man standing on both foot?',
#   'question_id': 524320000},
#  {'image_id': 524320,
#   'question': 'Was this picture likely taken recently?',
#   'question_id': 524320001},
#  {'image_id': 524320,
#   'question': "Do the gentleman's socks match his shoes and belt?",
#   'question_id': 524320002},
#  {'image_id': 240304,
#   'question': 'What is the zebra eating?',
#   'question_id': 240304000},
#  {'image_id': 240304,
#   'question': 'Are the zebras facing the same direction?',
#   'question_id': 240304001},
#  {'image_id': 240304,
#   'question': 'What is the tree covered with?',
#   'question_id': 240304002},
#  {'image_id': 34, 'question': 'Is this a horse?', 'question_id': 34000},
#  {'image_id': 34,
#   'question': 'What is the animal eating?',
#   'question_id': 34001},
#  {'image_id': 34, 'question': 'How old is animal?', 'question_id': 34002},
#  {'image_id': 393251,
#   'question': "Are they drinking wine at the child's party?",
#   'question_id': 393251000},
#  {'image_id': 393251,
#   'question': 'Is the man wearing glasses?',
#   'question_id': 393251001},
#  {'image_id': 393251,
#   'question': 'What is the man holding?',
#   'question_id': 393251002},
#  {'image_id': 393251,
#   'question': 'What is the man cutting?',
#   'question_id': 393251003},
#  {'image_id': 262180,
#   'question': 'What is the fruit?',
#   'question_id': 262180000},
#  {'image_id': 262180,
#   'question': 'Is this a good dessert?',
#   'question_id': 262180001},
#  {'image_id': 262180,
#   'question': 'What is the name of the type of person that would make this food?',
#   'question_id': 262180002},
#  {'image_id': 262180,
#   'question': 'What type of ice cream is on the plate?',
#   'question_id': 262180003},
#  {'image_id': 524325,
#   'question': 'How many people are wearing shorts in the forefront of this photo?',
#   'question_id': 524325000},
#  {'image_id': 524325,
#   'question': 'Is this an indoor or outdoor photo?',
#   'question_id': 524325001},
#  {'image_id': 524325,
#   'question': 'Are those kites in the air?',
#   'question_id': 524325002},
#  {'image_id': 43697,
#   'question': 'Is this a hot dog?',
#   'question_id': 43697000},
#  {'image_id': 43697,
#   'question': 'What color is the napkin?',
#   'question_id': 43697001},
#  {'image_id': 43697,
#   'question': 'Is there ketchup on the hot dog?',
#   'question_id': 43697002},
#  {'image_id': 43697,
#   'question': 'Has this hot dog been grilled?',
#   'question_id': 43697003},
#  {'image_id': 43697,
#   'question': 'Have you tried a hot dog like this before?',
#   'question_id': 43697004},
#  {'image_id': 43697,
#   'question': "What's missing from this hot dog?",
#   'question_id': 43697005},
#  {'image_id': 43697,
#   'question': 'What is the hog dog sitting on?',
#   'question_id': 43697006},
#  {'image_id': 262184,
#   'question': 'Is this a toy-sized truck?',
#   'question_id': 262184000},
#  {'image_id': 262184,
#   'question': 'What is the sky full of?',
#   'question_id': 262184001},
#  {'image_id': 262184,
#   'question': 'Where are the trucks?',
#   'question_id': 262184002},
#  {'image_id': 131113,
#   'question': 'What is the color of the carpet?',
#   'question_id': 131113000},
#  {'image_id': 131113,
#   'question': 'Is there a carpet on the floor?',
#   'question_id': 131113001},
#  {'image_id': 131113,
#   'question': 'What color is the refrigerator?',
#   'question_id': 131113002},
#  {'image_id': 131113,
#   'question': 'What is this device?',
#   'question_id': 131113003},
#  {'image_id': 262187,
#   'question': 'Is this plane landing?',
#   'question_id': 262187000},
#  {'image_id': 262187,
#   'question': 'What color is the plane?',
#   'question_id': 262187001},
#  {'image_id': 262187,
#   'question': 'What shape are the windows on the side of the plane?',
#   'question_id': 262187002},
#  {'image_id': 262187,
#   'question': 'Is the plane taking off?',
#   'question_id': 262187003},
#  {'image_id': 131118,
#   'question': 'Are these airliners?',
#   'question_id': 131118000},
#  {'image_id': 131118,
#   'question': 'How many planes are in the picture?',
#   'question_id': 131118001},
#  {'image_id': 131118,
#   'question': 'Are this cargo planes?',
#   'question_id': 131118002},
#  {'image_id': 262191,
#   'question': 'Is this bear a normal size?',
#   'question_id': 262191000},
#  {'image_id': 262191,
#   'question': 'What is the website on the sign?',
#   'question_id': 262191001},
#  {'image_id': 262191,
#   'question': 'What is the bear called?',
#   'question_id': 262191002},
#  {'image_id': 49,
#   'question': 'Is there a flower arrangement on the lawn?',
#   'question_id': 49000},
#  {'image_id': 49,
#   'question': 'What color horse is closer to the camera?',
#   'question_id': 49001},
#  {'image_id': 49, 'question': 'Are they playing polo?', 'question_id': 49002},
#  {'image_id': 524338,
#   'question': 'How many trees are in this photo?',
#   'question_id': 524338000},
#  {'image_id': 524338,
#   'question': 'What type of tree is the man standing next to?',
#   'question_id': 524338001},
#  {'image_id': 524338,
#   'question': 'Is this man reading a cell phone screen?',
#   'question_id': 524338002},
#  {'image_id': 213863,
#   'question': 'What pattern is on the pants?',
#   'question_id': 213863000},
#  {'image_id': 213863,
#   'question': 'What sport is this person playing?',
#   'question_id': 213863001},
#  {'image_id': 213863,
#   'question': 'What is the position of the player behind the batter called?',
#   'question_id': 213863002},
#  {'image_id': 393268,
#   'question': "What color is the girl's shirt?",
#   'question_id': 393268000},
#  {'image_id': 393268,
#   'question': 'What are they drinking?',
#   'question_id': 393268001},
#  {'image_id': 393268,
#   'question': 'What brand of beer is visible?',
#   'question_id': 393268002},
#  {'image_id': 131126,
#   'question': 'Where is Brooklyn Avenue?',
#   'question_id': 131126000},
#  {'image_id': 131126,
#   'question': 'Which direction is Brooklyn Ave?',
#   'question_id': 131126001},
#  {'image_id': 131126,
#   'question': 'Is there a stop sign in the picture?',
#   'question_id': 131126002},
#  {'image_id': 131127,
#   'question': "What logo is on the man's shirt?",
#   'question_id': 131127000},
#  {'image_id': 131127,
#   'question': 'Is the man unhappy?',
#   'question_id': 131127001},
#  {'image_id': 131127,
#   'question': 'Are the men going to share the bananas?',
#   'question_id': 131127002},
#  {'image_id': 131128,
#   'question': 'What color are the flowers?',
#   'question_id': 131128000},
#  {'image_id': 131128,
#   'question': 'What colors are the flowers?',
#   'question_id': 131128001},
#  {'image_id': 131128,
#   'question': 'How many flowers are painted on the vase?',
#   'question_id': 131128002},
#  {'image_id': 131128,
#   'question': 'Do the painted flowers match the real ones?',
#   'question_id': 131128003},
#  {'image_id': 262201,
#   'question': 'Where is the bird?',
#   'question_id': 262201000},
#  {'image_id': 262201,
#   'question': 'Will the birds go into the water?',
#   'question_id': 262201001},
#  {'image_id': 262201,
#   'question': 'What direction is the bird looking?',
#   'question_id': 262201002},
#  {'image_id': 262201,
#   'question': 'Is this bird afraid of the ledge?',
#   'question_id': 262201003},
#  {'image_id': 370986,
#   'question': 'What time of day is it?',
#   'question_id': 370986000},
#  {'image_id': 370986,
#   'question': 'How many elephants are in the water?',
#   'question_id': 370986001},
#  {'image_id': 370986,
#   'question': 'How many tails can you see in this picture?',
#   'question_id': 370986002},
#  {'image_id': 262204,
#   'question': 'How many tusks are visible?',
#   'question_id': 262204000},
#  {'image_id': 262204,
#   'question': 'What is this animal?',
#   'question_id': 262204001},
#  {'image_id': 262204,
#   'question': 'What color is the animal?',
#   'question_id': 262204002},
#  {'image_id': 131133,
#   'question': 'What color is the plane?',
#   'question_id': 131133000},
#  {'image_id': 131133,
#   'question': 'What type of plane is this?',
#   'question_id': 131133001},
#  {'image_id': 131133,
#   'question': 'Are the mountains high?',
#   'question_id': 131133002},
#  {'image_id': 262207,
#   'question': 'What color are the seats?',
#   'question_id': 262207000},
#  {'image_id': 262207,
#   'question': 'Is there a person standing in front of the television?',
#   'question_id': 262207001},
#  {'image_id': 262207,
#   'question': 'Where is the mirror?',
#   'question_id': 262207002},
#  {'image_id': 262207,
#   'question': 'Is there enough room under the armchairs for a cat to hide?',
#   'question_id': 262207003},
#  {'image_id': 64, 'question': 'Who made the cock?', 'question_id': 64000},
#  {'image_id': 64,
#   'question': 'Are there numbers on the clock face?',
#   'question_id': 64001},
#  {'image_id': 64,
#   'question': 'Is there a big tree behind the clock?',
#   'question_id': 64002},
#  {'image_id': 64, 'question': 'What is in the picture?', 'question_id': 64003},
#  {'image_id': 64,
#   'question': 'What time is the clock showing?',
#   'question_id': 64004},
#  {'image_id': 458763,
#   'question': 'What are the vases sitting on?',
#   'question_id': 458763000},
#  {'image_id': 458763,
#   'question': 'How many trees on the table?',
#   'question_id': 458763001},
#  {'image_id': 458763,
#   'question': 'How many horns are in the picture?',
#   'question_id': 458763002},
#  {'image_id': 458763,
#   'question': 'What color is the middle vase?',
#   'question_id': 458763003},
#  {'image_id': 458763,
#   'question': 'What is the table made of?',
#   'question_id': 458763004},
#  {'image_id': 458763,
#   'question': 'What kind of trees are on the table?',
#   'question_id': 458763005},
#  {'image_id': 458763,
#   'question': 'Is this a wedding?',
#   'question_id': 458763006},
#  {'image_id': 567990,
#   'question': 'What is the green stuff on this pizza?',
#   'question_id': 567990000},
#  {'image_id': 567990,
#   'question': 'Does the crust look burnt?',
#   'question_id': 567990001},
#  {'image_id': 567990,
#   'question': 'Is it thick or thin crust?',
#   'question_id': 567990002},
#  {'image_id': 567990,
#   'question': 'Does this pizza have a deep dish crust?',
#   'question_id': 567990003},
#  {'image_id': 393286,
#   'question': 'Is the banana freshly peeled?',
#   'question_id': 393286000},
#  {'image_id': 393286,
#   'question': 'Is the banana closed?',
#   'question_id': 393286001},
#  {'image_id': 393286,
#   'question': 'What is the orange thing?',
#   'question_id': 393286002},
#  {'image_id': 71,
#   'question': 'Does this photo show train tracks?',
#   'question_id': 71000},
#  {'image_id': 71, 'question': 'Does this train work?', 'question_id': 71001},
#  {'image_id': 71,
#   'question': 'Is this train headed towards or from the orange building?',
#   'question_id': 71002},
#  {'image_id': 72,
#   'question': 'How many Giraffes are in this image?',
#   'question_id': 72000},
#  {'image_id': 72,
#   'question': 'What is the giraffe eating?',
#   'question_id': 72001},
#  {'image_id': 72,
#   'question': 'Are the giraffes under the trees?',
#   'question_id': 72002},
#  {'image_id': 393228,
#   'question': 'Are there 3 elephants?',
#   'question_id': 393228000},
#  {'image_id': 393228,
#   'question': 'Are all of the elephants full grown?',
#   'question_id': 393228001},
#  {'image_id': 393228,
#   'question': 'Are the elephants in the jungle?',
#   'question_id': 393228002},
#  {'image_id': 393290,
#   'question': "What is on the woman's neck?",
#   'question_id': 393290000},
#  {'image_id': 393290,
#   'question': 'Is the woman eating the pizza?',
#   'question_id': 393290001},
#  {'image_id': 393290,
#   'question': 'How many stairs are there?',
#   'question_id': 393290002},
#  {'image_id': 393291,
#   'question': 'Where is the sink located?',
#   'question_id': 393291000},
#  {'image_id': 393291,
#   'question': 'Where is the soap?',
#   'question_id': 393291001},
#  {'image_id': 393291,
#   'question': 'What color is the window frame?',
#   'question_id': 393291002},
#  {'image_id': 393291,
#   'question': 'What item is folded up and sitting on the edge of the shower stall?',
#   'question_id': 393291003},
#  {'image_id': 393291,
#   'question': 'What pattern is on the shower curtain?',
#   'question_id': 393291004},
#  {'image_id': 393291,
#   'question': 'What are the colors of the countertop?',
#   'question_id': 393291005},
#  {'image_id': 393291,
#   'question': 'Are there any reflections in this picture?',
#   'question_id': 393291006},
#  {'image_id': 393291,
#   'question': 'How many windows are there?',
#   'question_id': 393291007},
#  {'image_id': 393292,
#   'question': 'Is the water on?',
#   'question_id': 393292000},
#  {'image_id': 393292,
#   'question': 'Is this photo outdoors?',
#   'question_id': 393292001},
#  {'image_id': 393292,
#   'question': 'How many birds are in the sink?',
#   'question_id': 393292002},
#  {'image_id': 262221,
#   'question': 'What is the person on the right called?',
#   'question_id': 262221000},
#  {'image_id': 262221,
#   'question': "Whose logo is on the official's chair?",
#   'question_id': 262221001},
#  {'image_id': 262221,
#   'question': 'How many tennis players are in the photo?',
#   'question_id': 262221002},
#  {'image_id': 78,
#   'question': 'Are the clock and owl made in the same artistic fashion?',
#   'question_id': 78000},
#  {'image_id': 78, 'question': 'Is that owl a candle?', 'question_id': 78001},
#  {'image_id': 78,
#   'question': 'What time does the clock say?',
#   'question_id': 78002},
#  {'image_id': 81,
#   'question': 'Does this planes tail have 4 colors?',
#   'question_id': 81000},
#  {'image_id': 81, 'question': 'Is this plane landing?', 'question_id': 81001},
#  {'image_id': 81,
#   'question': 'Is this plane taking off?',
#   'question_id': 81002},
#  {'image_id': 81,
#   'question': 'What is the last letter over the plane?',
#   'question_id': 81003},
#  {'image_id': 81, 'question': 'Are these wings strong?', 'question_id': 81004},
#  {'image_id': 86, 'question': 'Is that a bicycle?', 'question_id': 86000},
#  {'image_id': 86,
#   'question': 'What is the number on the mailbox?',
#   'question_id': 86001},
#  {'image_id': 86,
#   'question': 'What is this person wearing on head?',
#   'question_id': 86002},
#  {'image_id': 524375,
#   'question': 'Is this a cow farm?',
#   'question_id': 524375000},
#  {'image_id': 524375,
#   'question': 'What are the animals doing?',
#   'question_id': 524375001},
#  {'image_id': 524375,
#   'question': 'What breed of livestock is shown?',
#   'question_id': 524375002},
#  {'image_id': 524375,
#   'question': 'How many black sheep are there?',
#   'question_id': 524375003},
#  {'image_id': 524375,
#   'question': 'What game would you play when you saw this as a child?',
#   'question_id': 524375004},
#  {'image_id': 524375,
#   'question': 'Where is the human?',
#   'question_id': 524375005},
#  {'image_id': 524375,
#   'question': 'Is this a prairie?',
#   'question_id': 524375006},
#  {'image_id': 524375,
#   'question': 'Is there a village in the background?',
#   'question_id': 524375007},
#  {'image_id': 131160,
#   'question': 'What color is the sign?',
#   'question_id': 131160000},
#  {'image_id': 131160,
#   'question': 'Would you be able to find a mosque in this city?',
#   'question_id': 131160001},
#  {'image_id': 131160,
#   'question': 'What language is the sign written in?',
#   'question_id': 131160002},
#  {'image_id': 524377,
#   'question': 'How has the cheese been prepared?',
#   'question_id': 524377000},
#  {'image_id': 524377,
#   'question': 'Is there ketchup?',
#   'question_id': 524377001},
#  {'image_id': 524377,
#   'question': 'How many lunches is this?',
#   'question_id': 524377002},
#  {'image_id': 524377,
#   'question': 'Is the hotdog well seasoned?',
#   'question_id': 524377003},
#  {'image_id': 524377,
#   'question': 'What kind of food is shown?',
#   'question_id': 524377004},
#  {'image_id': 524377,
#   'question': 'What is the cutting board used for in this scene?',
#   'question_id': 524377005},
#  {'image_id': 524377,
#   'question': 'Of what meal is this kind of food typical?',
#   'question_id': 524377006},
#  {'image_id': 524377,
#   'question': 'Is this a healthy meal?',
#   'question_id': 524377007},
#  {'image_id': 524377,
#   'question': 'What kind of sauce is in the largest ramekin?',
#   'question_id': 524377008},
#  {'image_id': 524377,
#   'question': 'What type of food is shown?',
#   'question_id': 524377009},
#  {'image_id': 524377,
#   'question': 'What is the topping on the hot dog?',
#   'question_id': 524377010},
#  {'image_id': 524377,
#   'question': 'What topping is on the hot dog?',
#   'question_id': 524377011},
#  {'image_id': 524377,
#   'question': 'What is in the small container?',
#   'question_id': 524377012},
#  {'image_id': 524377,
#   'question': 'What are the components of this dish?',
#   'question_id': 524377013},
#  {'image_id': 524377,
#   'question': 'What kind of toppings are on the hot dogs?',
#   'question_id': 524377014},
#  {'image_id': 524377,
#   'question': 'Is there a spoon in this photo?',
#   'question_id': 524377015},
#  {'image_id': 524377,
#   'question': 'Is this breakfast?',
#   'question_id': 524377016},
#  {'image_id': 524377,
#   'question': 'How delicious does this look?',
#   'question_id': 524377017},
#  {'image_id': 524377,
#   'question': 'What two vegetables are in the white bowl?',
#   'question_id': 524377018},
#  {'image_id': 524377,
#   'question': 'How many hot dogs are shown?',
#   'question_id': 524377019},
#  {'image_id': 524377,
#   'question': 'What type of filling is in the dish on the bottom left?',
#   'question_id': 524377020},
#  {'image_id': 524377,
#   'question': 'What color is the tray?',
#   'question_id': 524377021},
#  {'image_id': 524377,
#   'question': 'How many pickle spears are there?',
#   'question_id': 524377022},
#  {'image_id': 524377,
#   'question': 'What is the yellow stuff in a bowl?',
#   'question_id': 524377023},
#  {'image_id': 524377,
#   'question': 'How many people are eating this hotdog?',
#   'question_id': 524377024},
#  {'image_id': 524377,
#   'question': 'Is there a drink in this picture?',
#   'question_id': 524377025},
#  {'image_id': 524377,
#   'question': 'What is the hot dog sitting on top of?',
#   'question_id': 524377026},
#  {'image_id': 524377,
#   'question': 'How many sauces are there?',
#   'question_id': 524377027},
#  {'image_id': 524377,
#   'question': 'What are the orange things?',
#   'question_id': 524377028},
#  {'image_id': 524377,
#   'question': 'Are the carrots diced or cut long ways?',
#   'question_id': 524377029},
#  {'image_id': 524377,
#   'question': 'Do these hot dogs look like they taste good?',
#   'question_id': 524377030},
#  {'image_id': 524377,
#   'question': 'Are those tomatoes on the sandwich?',
#   'question_id': 524377031},
#  {'image_id': 524377,
#   'question': 'What is in the cup?',
#   'question_id': 524377032},
#  {'image_id': 524377,
#   'question': 'What is the orange root called?',
#   'question_id': 524377033},
#  {'image_id': 524377,
#   'question': 'What is the blackened meat on the bread?',
#   'question_id': 524377034},
#  {'image_id': 524377,
#   'question': 'What kind of meat is this?',
#   'question_id': 524377035},
#  {'image_id': 524377,
#   'question': 'What is on the sandwich?',
#   'question_id': 524377036},
#  {'image_id': 524377,
#   'question': 'Are the fries plain?',
#   'question_id': 524377037},
#  {'image_id': 524377,
#   'question': 'Does this breakfast dish primarily carbohydrates?',
#   'question_id': 524377038},
#  {'image_id': 524377,
#   'question': 'Has someone started eating?',
#   'question_id': 524377039},
#  {'image_id': 524377,
#   'question': 'What animal is on the plate?',
#   'question_id': 524377040},
#  {'image_id': 524377,
#   'question': 'Would this be good for dessert?',
#   'question_id': 524377041},
#  {'image_id': 524377,
#   'question': 'Is there a butter plate on the table?',
#   'question_id': 524377042},
#  {'image_id': 524377,
#   'question': 'Does this have lettuce?',
#   'question_id': 524377043},
#  {'image_id': 524377,
#   'question': 'Does the food look good?',
#   'question_id': 524377044},
#  {'image_id': 524377, 'question': 'Is this meat?', 'question_id': 524377045},
#  {'image_id': 524377,
#   'question': 'What is on the hotdog?',
#   'question_id': 524377046},
#  {'image_id': 524377,
#   'question': 'What two vegetables can be seen on the pizza?',
#   'question_id': 524377047},
#  {'image_id': 524377,
#   'question': 'Would this typically be eaten for breakfast?',
#   'question_id': 524377048},
#  {'image_id': 524377,
#   'question': 'Is that bacon from a delicatessen?',
#   'question_id': 524377049},
#  {'image_id': 524377,
#   'question': 'What condiment is on the potatoes?',
#   'question_id': 524377050},
#  {'image_id': 524377,
#   'question': 'How many kinds of meat products are here?',
#   'question_id': 524377051},
#  {'image_id': 524377,
#   'question': 'What sauces are shown?',
#   'question_id': 524377052},
#  {'image_id': 524377,
#   'question': 'What kind of potato are the fries?',
#   'question_id': 524377053},
#  {'image_id': 524377,
#   'question': 'What is mainly featured?',
#   'question_id': 524377054},
#  {'image_id': 393306,
#   'question': 'Is the man wearing formal clothes?',
#   'question_id': 393306000},
#  {'image_id': 393306,
#   'question': 'What kind of plants are these?',
#   'question_id': 393306001},
#  {'image_id': 393306,
#   'question': 'What is the pattern on the vase?',
#   'question_id': 393306002},
#  {'image_id': 393306,
#   'question': 'Which hand is the man holding up?',
#   'question_id': 393306003},
#  {'image_id': 262159,
#   'question': 'Is there a deodorant on the sink?',
#   'question_id': 262159000},
#  {'image_id': 262159,
#   'question': 'Is there a full roll of toilet paper in the bathroom?',
#   'question_id': 262159001},
#  {'image_id': 262159,
#   'question': 'How many rolls of toilet paper are on the toilet tank?',
#   'question_id': 262159002},
#  {'image_id': 262159,
#   'question': 'Would someone be able to watch you change from the outside?',
#   'question_id': 262159003},
#  {'image_id': 262159,
#   'question': 'What color is the bathroom?',
#   'question_id': 262159004},
#  {'image_id': 262159,
#   'question': 'Does the shower have a glass door?',
#   'question_id': 262159005},
#  {'image_id': 262159,
#   'question': 'What is the primary color of the bathroom?',
#   'question_id': 262159006},
#  {'image_id': 262159,
#   'question': 'What color is the wall?',
#   'question_id': 262159007},
#  {'image_id': 262159,
#   'question': 'Is the towel rack silver?',
#   'question_id': 262159008},
#  {'image_id': 262159,
#   'question': 'Is there a shower curtain?',
#   'question_id': 262159009},
#  {'image_id': 262159,
#   'question': 'What color are the bathroom walls?',
#   'question_id': 262159010},
#  {'image_id': 262159,
#   'question': 'Where is the light coming from?',
#   'question_id': 262159011},
#  {'image_id': 262159,
#   'question': 'Is the toilet lid down?',
#   'question_id': 262159012},
#  {'image_id': 92,
#   'question': 'How many layers are in this cake?',
#   'question_id': 92000},
#  {'image_id': 92,
#   'question': 'Does this cake look like it chocolate?',
#   'question_id': 92001},
#  {'image_id': 92,
#   'question': 'How many people can eat this cake?',
#   'question_id': 92002},
#  {'image_id': 94,
#   'question': 'What is printed on the orange sign?',
#   'question_id': 94000},
#  {'image_id': 94,
#   'question': 'What is the name of the hotel?',
#   'question_id': 94001},
#  {'image_id': 94,
#   'question': 'How many vehicles are shown?',
#   'question_id': 94002},
#  {'image_id': 94,
#   'question': 'What mode of transportation is pictured?',
#   'question_id': 94003},
#  {'image_id': 94, 'question': 'Is this a small town?', 'question_id': 94004},
#  {'image_id': 393311,
#   'question': 'Will these planes be used to transport people?',
#   'question_id': 393311000},
#  {'image_id': 393311,
#   'question': 'What airline is this?',
#   'question_id': 393311001},
#  {'image_id': 393311,
#   'question': "The plane's stand resembles what letter?",
#   'question_id': 393311002},
#  {'image_id': 393311,
#   'question': 'What type of plane is this?',
#   'question_id': 393311003},
#  {'image_id': 393311,
#   'question': 'What is written on the picture?',
#   'question_id': 393311004},
#  {'image_id': 393311,
#   'question': 'What shipping company is represented in the scene?',
#   'question_id': 393311005},
#  {'image_id': 393311,
#   'question': 'What airline is this plane from?',
#   'question_id': 393311006},
#  {'image_id': 393311,
#   'question': 'What kind of aircraft is this?',
#   'question_id': 393311007},
#  {'image_id': 393311,
#   'question': 'How does the man get down from the machine?',
#   'question_id': 393311008},
#  {'image_id': 524386,
#   'question': 'Is the room carpeted?',
#   'question_id': 524386000},
#  {'image_id': 524386,
#   'question': 'Where is the television?',
#   'question_id': 524386001},
#  {'image_id': 524386,
#   'question': 'Is there a fireplace?',
#   'question_id': 524386002},
#  {'image_id': 524386,
#   'question': 'Are stains on the floor?',
#   'question_id': 524386003},
#  {'image_id': 524386,
#   'question': 'How many lamps are there?',
#   'question_id': 524386004},
#  {'image_id': 524386,
#   'question': 'What is the picture of on wall?',
#   'question_id': 524386005},
#  {'image_id': 524386,
#   'question': 'What is on the carpet?',
#   'question_id': 524386006},
#  {'image_id': 524386,
#   'question': 'How many lamps are in the room?',
#   'question_id': 524386007},
#  {'image_id': 524386,
#   'question': 'Are these boys at home?',
#   'question_id': 524386008},
#  {'image_id': 524386,
#   'question': 'What kind of lamp is on the floor?',
#   'question_id': 524386009},
#  {'image_id': 524386,
#   'question': "Is this a 60's motif?",
#   'question_id': 524386010},
#  {'image_id': 524386,
#   'question': 'How many pictures on the wall?',
#   'question_id': 524386011},
#  {'image_id': 524386,
#   'question': 'Which floor lamp is not lit?',
#   'question_id': 524386012},
#  {'image_id': 524386,
#   'question': 'How many TVs are on?',
#   'question_id': 524386013},
#  {'image_id': 524386,
#   'question': 'What color is the sofa?',
#   'question_id': 524386014},
#  {'image_id': 524386,
#   'question': 'How many pictures are on the wall?',
#   'question_id': 524386015},
#  {'image_id': 131172,
#   'question': 'How many men in the picture are wearing sunglasses?',
#   'question_id': 131172000},
#  {'image_id': 131172,
#   'question': 'What kind of hat is the man with the girls wearing?',
#   'question_id': 131172001},
#  {'image_id': 131172,
#   'question': "What color is the man's shirt in the front of the photo?",
#   'question_id': 131172002},
#  {'image_id': 131172,
#   'question': 'What are the ladies doing?',
#   'question_id': 131172003},
#  {'image_id': 393317,
#   'question': 'Where is the street sign?',
#   'question_id': 393317000},
#  {'image_id': 393317,
#   'question': 'Where are the women walking?',
#   'question_id': 393317001},
#  {'image_id': 393317,
#   'question': 'Is the light green?',
#   'question_id': 393317002},
#  {'image_id': 393317,
#   'question': 'What is written on the street?',
#   'question_id': 393317003},
#  {'image_id': 393317, 'question': 'Is it raining?', 'question_id': 393317004},
#  {'image_id': 393317,
#   'question': 'Urban or suburban?',
#   'question_id': 393317005},
#  {'image_id': 393317,
#   'question': 'Where is the woman standing?',
#   'question_id': 393317006},
#  {'image_id': 393317,
#   'question': 'How many people can be seen?',
#   'question_id': 393317007},
#  {'image_id': 393317,
#   'question': 'What type of vehicle is on the left?',
#   'question_id': 393317008},
#  {'image_id': 393317,
#   'question': 'Is this woman crossing a street?',
#   'question_id': 393317009},
#  {'image_id': 393317,
#   'question': 'What color is the traffic signal?',
#   'question_id': 393317010},
#  {'image_id': 393317,
#   'question': 'What is being held green?',
#   'question_id': 393317011},
#  {'image_id': 393317,
#   'question': 'What time of day is it?',
#   'question_id': 393317012},
#  {'image_id': 393317,
#   'question': 'Is this in the United States?',
#   'question_id': 393317013},
#  {'image_id': 393317,
#   'question': 'How many green lights are there?',
#   'question_id': 393317014},
#  {'image_id': 131174,
#   'question': 'How many lights does the plane have?',
#   'question_id': 131174000},
#  {'image_id': 131174,
#   'question': 'How many planes are in this photo?',
#   'question_id': 131174001},
#  {'image_id': 131174,
#   'question': 'Is there anyone in the cockpit?',
#   'question_id': 131174002},
#  {'image_id': 546151,
#   'question': 'What country name is written as the highest word on the bus?',
#   'question_id': 546151000},
#  {'image_id': 546151,
#   'question': 'Is the bus stopped?',
#   'question_id': 546151001},
#  {'image_id': 546151,
#   'question': 'How many people are standing in this image?',
#   'question_id': 546151002},
#  {'image_id': 21826,
#   'question': 'What is the skier standing on?',
#   'question_id': 21826000},
#  {'image_id': 21826,
#   'question': 'How many poles is the person holding?',
#   'question_id': 21826001},
#  {'image_id': 21826,
#   'question': 'What is the person doing?',
#   'question_id': 21826002},
#  {'image_id': 109,
#   'question': 'Is this an ocean area?',
#   'question_id': 109000},
#  {'image_id': 109,
#   'question': 'How many bodies of water are in this scene?',
#   'question_id': 109001},
#  {'image_id': 109,
#   'question': 'How many light post is there?',
#   'question_id': 109002},
#  {'image_id': 109,
#   'question': 'Is the ground near the waterfront squishy?',
#   'question_id': 109003},
#  {'image_id': 109,
#   'question': 'What infrastructure would one drive on to go perpendicular to the water?',
#   'question_id': 109004},
#  {'image_id': 109, 'question': 'Is the water calm?', 'question_id': 109005},
#  {'image_id': 110,
#   'question': "What color is the woman's sweater?",
#   'question_id': 110000},
#  {'image_id': 110,
#   'question': 'Is this a cheese pizza?',
#   'question_id': 110001},
#  {'image_id': 110,
#   'question': 'What pizza topping is this?',
#   'question_id': 110002},
#  {'image_id': 305853,
#   'question': 'What is in the vase next to the flowers?',
#   'question_id': 305853000},
#  {'image_id': 305853,
#   'question': 'Is there more than one vase on the table?',
#   'question_id': 305853001},
#  {'image_id': 305853,
#   'question': 'Are these flowers real or silk?',
#   'question_id': 305853002},
#  {'image_id': 305853,
#   'question': "England's Queen mother and these blooms share what syllable?",
#   'question_id': 305853003},
#  {'image_id': 113,
#   'question': 'How many people are in the picture?',
#   'question_id': 113000},
#  {'image_id': 113,
#   'question': 'What color are the chairs?',
#   'question_id': 113001},
#  {'image_id': 113,
#   'question': 'What kind of celebration is this?',
#   'question_id': 113002},
#  {'image_id': 113,
#   'question': 'What emblem is on the cake?',
#   'question_id': 113003},
#  {'image_id': 113,
#   'question': 'Are they outside or in?',
#   'question_id': 113004},
#  {'image_id': 113, 'question': 'Is there a cake here?', 'question_id': 113005},
#  {'image_id': 113,
#   'question': 'Are there any pens on the table?',
#   'question_id': 113006},
#  {'image_id': 113,
#   'question': 'What are the initials on the cake?',
#   'question_id': 113007},
#  {'image_id': 262260,
#   'question': 'Why are the birds only appearing as black silhouettes?',
#   'question_id': 262260000},
#  {'image_id': 262260,
#   'question': 'How many pigeons are there?',
#   'question_id': 262260001},
#  {'image_id': 262260,
#   'question': 'Is this image tilted?',
#   'question_id': 262260002},
#  {'image_id': 262261,
#   'question': 'What utensil is in the pan?',
#   'question_id': 262261000},
#  {'image_id': 262261,
#   'question': 'What is the red vegetable in the clear dish?',
#   'question_id': 262261001},
#  {'image_id': 262261,
#   'question': 'Does this image contain a pie pan?',
#   'question_id': 262261002},
#  {'image_id': 131190,
#   'question': 'Is this a large house?',
#   'question_id': 131190000},
#  {'image_id': 131190,
#   'question': 'Is there a fountain in front of the building?',
#   'question_id': 131190001},
#  {'image_id': 131190,
#   'question': 'Is the sun shining?',
#   'question_id': 131190002},
#  {'image_id': 131190,
#   'question': 'What color is the building?',
#   'question_id': 131190003},
#  {'image_id': 131190,
#   'question': 'Is this a church?',
#   'question_id': 131190004},
#  {'image_id': 131190,
#   'question': 'What tree is on the left?',
#   'question_id': 131190005},
#  {'image_id': 131190,
#   'question': 'Are there clouds visible?',
#   'question_id': 131190006},
#  {'image_id': 131190,
#   'question': 'Is this a sunny day?',
#   'question_id': 131190007},
#  {'image_id': 131190,
#   'question': 'What is the material right around the clock?',
#   'question_id': 131190008},
#  {'image_id': 131190,
#   'question': 'What color are the flowers?',
#   'question_id': 131190009},
#  {'image_id': 131190,
#   'question': 'How many bells are there?',
#   'question_id': 131190010},
#  {'image_id': 131190,
#   'question': 'How tall is this building?',
#   'question_id': 131190011},
#  {'image_id': 131190,
#   'question': 'What materials are on the roof?',
#   'question_id': 131190012},
#  {'image_id': 131190,
#   'question': 'How many clock faces does this building have?',
#   'question_id': 131190013},
#  {'image_id': 131190,
#   'question': 'Are the hedges well-groomed?',
#   'question_id': 131190014},
#  {'image_id': 131190,
#   'question': 'Does the building in the back have an elevator?',
#   'question_id': 131190015},
#  {'image_id': 131190,
#   'question': 'What is in gold at the top of the building?',
#   'question_id': 131190016},
#  {'image_id': 131190,
#   'question': 'Do you a phone booth?',
#   'question_id': 131190017},
#  {'image_id': 131190,
#   'question': 'What color is the clock tower in this photo?',
#   'question_id': 131190018},
#  {'image_id': 131190,
#   'question': 'What are on both side of the building?',
#   'question_id': 131190019},
#  {'image_id': 131190,
#   'question': 'What is around the tree?',
#   'question_id': 131190020},
#  {'image_id': 131190,
#   'question': 'Are the buildings tall?',
#   'question_id': 131190021},
#  {'image_id': 131190,
#   'question': "How many flags are by the building's entrance?",
#   'question_id': 131190022},
#  {'image_id': 131190,
#   'question': 'Is the clock between two arches?',
#   'question_id': 131190023},
#  {'image_id': 131190,
#   'question': 'Are there any entrance gates at the bottom of the tower?',
#   'question_id': 131190024},
#  {'image_id': 131190,
#   'question': 'Is the building a high rise?',
#   'question_id': 131190025},
#  {'image_id': 131190,
#   'question': 'Is part of this tower made of wood?',
#   'question_id': 131190026},
#  {'image_id': 131190,
#   'question': 'Can the tree tell time?',
#   'question_id': 131190027},
#  {'image_id': 131190,
#   'question': 'How many windows are shown?',
#   'question_id': 131190028},
#  {'image_id': 131190,
#   'question': 'How many windows are pictured?',
#   'question_id': 131190029},
#  {'image_id': 131190,
#   'question': 'Is the emblem a sun face clock?',
#   'question_id': 131190030},
#  {'image_id': 131197,
#   'question': 'What is the woman doing in this photo?',
#   'question_id': 131197000},
#  {'image_id': 131197,
#   'question': 'What are the sheep standing on?',
#   'question_id': 131197001},
#  {'image_id': 131197,
#   'question': 'What is the woman feeding the animal?',
#   'question_id': 131197002},
#  {'image_id': 131197,
#   'question': 'How many sheep can you see?',
#   'question_id': 131197003},
#  {'image_id': 131197,
#   'question': "Is the ram's fleece dirty?",
#   'question_id': 131197004},
#  {'image_id': 127,
#   'question': 'Is there a travel guide on the table?',
#   'question_id': 127000},
#  {'image_id': 127,
#   'question': 'What color plate is this?',
#   'question_id': 127001},
#  {'image_id': 127,
#   'question': 'What type of silverware is on the plates?',
#   'question_id': 127002},
#  {'image_id': 262273,
#   'question': 'What color are the skis?',
#   'question_id': 262273000},
#  {'image_id': 262273, 'question': 'Is there snow?', 'question_id': 262273001},
#  {'image_id': 262273,
#   'question': 'What is the man holding in his left hand?',
#   'question_id': 262273002},
#  {'image_id': 262273,
#   'question': 'What is the color of the zipper?',
#   'question_id': 262273003},
#  {'image_id': 262273,
#   'question': 'Are the boots a solid color or patterned?',
#   'question_id': 262273004},
#  {'image_id': 262273,
#   'question': 'How many people are there?',
#   'question_id': 262273005},
#  {'image_id': 262273, 'question': 'Is it summer?', 'question_id': 262273006},
#  {'image_id': 262273,
#   'question': "What color is the man's hat?",
#   'question_id': 262273007},
#  {'image_id': 262273,
#   'question': 'How many people are in the image?',
#   'question_id': 262273008},
#  {'image_id': 524420,
#   'question': "What color is the woman's shorts?",
#   'question_id': 524420000},
#  {'image_id': 524420,
#   'question': 'Is the picture in color?',
#   'question_id': 524420001},
#  {'image_id': 524420,
#   'question': 'Is there a dog in the photo?',
#   'question_id': 524420002},
#  {'image_id': 524420,
#   'question': 'Is the dog on a leash?',
#   'question_id': 524420003},
#  {'image_id': 524420,
#   'question': 'What are the people doing in the street?',
#   'question_id': 524420004},
#  {'image_id': 436929,
#   'question': 'What is floating near the bird?',
#   'question_id': 436929000},
#  {'image_id': 436929,
#   'question': 'Are all of the birds in flight?',
#   'question_id': 436929001},
#  {'image_id': 436929,
#   'question': 'How many birds are there?',
#   'question_id': 436929002},
#  {'image_id': 436929,
#   'question': 'Are there three birds in the picture?',
#   'question_id': 436929003},
# ...
#   'question_id': 131339002},
#  {'image_id': 131339,
#   'question': 'Is this man riding a surfboard?',
#   'question_id': 131339003},
#  {'image_id': 131339,
#   'question': 'Is he wearing the right type of suit?',
#   'question_id': 131339004},
#  {'image_id': 131339,
#   'question': 'Is the man riding a white board?',
#   'question_id': 131339005},
#  {'image_id': 131339,
#   'question': 'How many people are surfing?',
#   'question_id': 131339006},
#  {'image_id': 131339,
#   'question': 'Is the woman surfing?',
#   'question_id': 131339007},
#  {'image_id': 131339,
#   'question': 'What kind of suit is he wearing?',
#   'question_id': 131339008},
#  {'image_id': 524557,
#   'question': 'What sport are they playing?',
#   'question_id': 524557000},
#  {'image_id': 524557,
#   'question': 'Color is the goaltenders shirt?',
#   'question_id': 524557001},
#  {'image_id': 524557,
#   'question': 'Where is number 8?',
#   'question_id': 524557002},
#  {'image_id': 524557,
#   'question': 'How many kids are wearing black and white?',
#   'question_id': 524557003},
#  {'image_id': 524557,
#   'question': 'Is the boy in the middle being attacked?',
#   'question_id': 524557004},
#  {'image_id': 524557,
#   'question': 'Does the boy have his head stuck in the net?',
#   'question_id': 524557005},
#  {'image_id': 131342,
#   'question': 'How many men are wearing hats?',
#   'question_id': 131342000},
#  {'image_id': 131342,
#   'question': 'Does the guy on the right look happy?',
#   'question_id': 131342001},
#  {'image_id': 131342,
#   'question': 'Are they coworkers or best friends?',
#   'question_id': 131342002},
#  {'image_id': 131342,
#   'question': 'What is in the glass in the lower right?',
#   'question_id': 131342003},
#  {'image_id': 131342,
#   'question': 'The wall is made out of?',
#   'question_id': 131342004},
#  {'image_id': 262415,
#   'question': 'What does the sign in the background say?',
#   'question_id': 262415000},
#  {'image_id': 262415,
#   'question': 'What color is the bus in the mirror?',
#   'question_id': 262415001},
#  {'image_id': 262415,
#   'question': 'What is behind the mirror?',
#   'question_id': 262415002},
#  {'image_id': 262415,
#   'question': 'What kind of passenger does the bus carry?',
#   'question_id': 262415003},
#  {'image_id': 393488,
#   'question': 'How healthy does this meal look?',
#   'question_id': 393488000},
#  {'image_id': 393488,
#   'question': 'Are there multiple vegetables on the plate?',
#   'question_id': 393488001},
#  {'image_id': 393488,
#   'question': 'What meat is used in the main dish?',
#   'question_id': 393488002},
#  {'image_id': 393488,
#   'question': 'Is there meat on the plate?',
#   'question_id': 393488003},
#  {'image_id': 393489,
#   'question': 'What is the man reaching for?',
#   'question_id': 393489000},
#  {'image_id': 393489,
#   'question': 'Is this a brand new phone?',
#   'question_id': 393489001},
#  {'image_id': 393489,
#   'question': 'What kind of id is that?',
#   'question_id': 393489002},
#  {'image_id': 393489,
#   'question': 'What color is the phone?',
#   'question_id': 393489003},
#  {'image_id': 393489,
#   'question': 'Does this phone fold closed?',
#   'question_id': 393489004},
#  {'image_id': 393489,
#   'question': 'What language is the text on the sign?',
#   'question_id': 393489005},
#  {'image_id': 393489,
#   'question': 'How many holes are on the phone case?',
#   'question_id': 393489006},
#  {'image_id': 393489,
#   'question': 'What is the man holding?',
#   'question_id': 393489007},
#  {'image_id': 393489,
#   'question': 'What does this phone case look like?',
#   'question_id': 393489008},
#  {'image_id': 393489,
#   'question': 'What is the brand of the phone?',
#   'question_id': 393489009},
#  {'image_id': 393489,
#   'question': 'Is the phone broken?',
#   'question_id': 393489010},
#  {'image_id': 393489,
#   'question': 'What does this controller go with?',
#   'question_id': 393489011},
#  {'image_id': 393489,
#   'question': 'Is the phone light on?',
#   'question_id': 393489012},
#  {'image_id': 393489,
#   'question': 'Which hand is the person holding the phone in?',
#   'question_id': 393489013},
#  {'image_id': 393489,
#   'question': 'Is the display on?',
#   'question_id': 393489014},
#  {'image_id': 393489,
#   'question': 'Is the person using skype?',
#   'question_id': 393489015},
#  {'image_id': 393489,
#   'question': 'How many phones do you see?',
#   'question_id': 393489016},
#  {'image_id': 393489,
#   'question': 'Is the phone on?',
#   'question_id': 393489017},
#  {'image_id': 393489,
#   'question': 'Is the background clear?',
#   'question_id': 393489018},
#  {'image_id': 393489,
#   'question': 'What brand is the phone?',
#   'question_id': 393489019},
#  {'image_id': 393489,
#   'question': 'What kind of phone is this?',
#   'question_id': 393489020},
#  {'image_id': 393489,
#   'question': 'What is the person holding in their hand?',
#   'question_id': 393489021},
#  {'image_id': 393489,
#   'question': 'What is the person holding?',
#   'question_id': 393489022},
#  {'image_id': 336077,
#   'question': 'Is this an inside stadium?',
#   'question_id': 336077000},
#  {'image_id': 336077,
#   'question': 'Is the stadium crowded?',
#   'question_id': 336077001},
#  {'image_id': 336077,
#   'question': 'Is the stadium full?',
#   'question_id': 336077002},
#  {'image_id': 336077,
#   'question': 'Is there a baseball player holding a bat?',
#   'question_id': 336077003},
#  {'image_id': 546179,
#   'question': 'Is this bathroom all white?',
#   'question_id': 546179000},
#  {'image_id': 546179,
#   'question': 'Has the bathroom been renovated recently?',
#   'question_id': 546179001},
#  {'image_id': 546179,
#   'question': "What's on the other side of the shower curtain?",
#   'question_id': 546179002},
#  {'image_id': 546179,
#   'question': 'Are there towels on the ground?',
#   'question_id': 546179003},
#  {'image_id': 546179,
#   'question': 'What color is the shower curtain?',
#   'question_id': 546179004},
#  {'image_id': 546179,
#   'question': 'Does this look clean?',
#   'question_id': 546179005},
#  {'image_id': 546179,
#   'question': 'Where is the shower located?',
#   'question_id': 546179006},
#  {'image_id': 546179,
#   'question': 'Is the shower curtain open?',
#   'question_id': 546179007},
#  {'image_id': 9,
#   'question': 'How many cookies can be seen?',
#   'question_id': 9000},
#  {'image_id': 9,
#   'question': 'What color are the dishes?',
#   'question_id': 9001},
#  {'image_id': 9, 'question': 'What is the green stuff?', 'question_id': 9002},
#  {'image_id': 393493,
#   'question': 'Does this bike have training wheels?',
#   'question_id': 393493000},
#  {'image_id': 393493,
#   'question': 'How many girls are visible?',
#   'question_id': 393493001},
#  {'image_id': 393493,
#   'question': 'Is the picnic table red?',
#   'question_id': 393493002},
#  {'image_id': 131351,
#   'question': 'Is this a clean room?',
#   'question_id': 131351000},
#  {'image_id': 131351,
#   'question': 'How many colors are in the tile?',
#   'question_id': 131351001},
#  {'image_id': 131351,
#   'question': 'What is the floor made of?',
#   'question_id': 131351002},
#  {'image_id': 131351,
#   'question': 'Is this bathroom clean?',
#   'question_id': 131351003},
#  {'image_id': 131351,
#   'question': 'Is the room clean?',
#   'question_id': 131351004},
#  {'image_id': 131351,
#   'question': 'What color is the water in the bathtub?',
#   'question_id': 131351005},
#  {'image_id': 131351,
#   'question': 'Is there a mirror in the bathroom?',
#   'question_id': 131351006},
#  {'image_id': 131351,
#   'question': 'What is the ratio of white tiles to blue?',
#   'question_id': 131351007},
#  {'image_id': 131351,
#   'question': 'Is there a green plant in this room?',
#   'question_id': 131351008},
#  {'image_id': 131351,
#   'question': 'What power tool is present?',
#   'question_id': 131351009},
#  {'image_id': 131351,
#   'question': 'Is this room clean?',
#   'question_id': 131351010},
#  {'image_id': 131352,
#   'question': 'What fruit is present?',
#   'question_id': 131352000},
#  {'image_id': 131352,
#   'question': 'What color are these mattresses?',
#   'question_id': 131352001},
#  {'image_id': 131352,
#   'question': 'Which room is this?',
#   'question_id': 131352002},
#  {'image_id': 524572,
#   'question': 'Where is the cat sitting?',
#   'question_id': 524572000},
#  {'image_id': 524572,
#   'question': 'What do you think the cat is looking at?',
#   'question_id': 524572001},
#  {'image_id': 524572,
#   'question': 'Is the cat trying to catch a bird?',
#   'question_id': 524572002},
#  {'image_id': 112497,
#   'question': 'What utensil is sitting next to the food?',
#   'question_id': 112497000},
#  {'image_id': 112497,
#   'question': 'What is in the jug?',
#   'question_id': 112497001},
#  {'image_id': 112497,
#   'question': 'What is the name of this crusted food?',
#   'question_id': 112497002},
#  {'image_id': 393503,
#   'question': 'What color are the items on the truck?',
#   'question_id': 393503000},
#  {'image_id': 393503,
#   'question': 'Is the writing in French?',
#   'question_id': 393503001},
#  {'image_id': 393503,
#   'question': 'Is this a traveling circus?',
#   'question_id': 393503002},
#  {'image_id': 393503,
#   'question': 'What animal is on the flatbed?',
#   'question_id': 393503003},
#  {'image_id': 393508,
#   'question': 'What room of the house is this?',
#   'question_id': 393508000},
#  {'image_id': 393508,
#   'question': 'What is the floor made out of?',
#   'question_id': 393508001},
#  {'image_id': 393508,
#   'question': 'What do you use the stove for?',
#   'question_id': 393508002},
#  {'image_id': 414639,
#   'question': 'What is the batter wearing on his ankles?',
#   'question_id': 414639000},
#  {'image_id': 414639,
#   'question': 'Are there long lenses?',
#   'question_id': 414639001},
#  {'image_id': 414639,
#   'question': 'What is the crouching man in the mask called?',
#   'question_id': 414639002},
#  {'image_id': 131366,
#   'question': 'How many people are standing next to each other?',
#   'question_id': 131366000},
#  {'image_id': 131366,
#   'question': 'What are the two women carrying?',
#   'question_id': 131366001},
#  {'image_id': 131366,
#   'question': 'What are these people holding?',
#   'question_id': 131366002},
#  {'image_id': 131366,
#   'question': 'How many rackets?',
#   'question_id': 131366003},
#  {'image_id': 131366,
#   'question': 'How many people are in this photo?',
#   'question_id': 131366004},
#  {'image_id': 131366,
#   'question': 'What is the woman wearing on her neck?',
#   'question_id': 131366005},
#  {'image_id': 131366,
#   'question': 'Is everyone wearing long sleeves?',
#   'question_id': 131366006},
#  {'image_id': 131366,
#   'question': 'What sports are they playing?',
#   'question_id': 131366007},
#  {'image_id': 131366,
#   'question': 'What is the approximate time period of this photo?',
#   'question_id': 131366008},
#  {'image_id': 131366,
#   'question': 'How many girls are in the picture?',
#   'question_id': 131366009},
#  {'image_id': 131366,
#   'question': 'Which two are actually playing?',
#   'question_id': 131366010},
#  {'image_id': 131366,
#   'question': 'Are the woman wearing short dresses?',
#   'question_id': 131366011},
#  {'image_id': 131366,
#   'question': 'Is the lady smiling?',
#   'question_id': 131366012},
#  {'image_id': 131366,
#   'question': 'Do they play for Red Sox?',
#   'question_id': 131366013},
#  {'image_id': 131366,
#   'question': 'What are the ladies doing?',
#   'question_id': 131366014},
#  {'image_id': 131366,
#   'question': 'What three letter word, best describes the liquid container on the ground between the two people?',
#   'question_id': 131366015},
#  {'image_id': 131366,
#   'question': 'What does the wall say on the far left?',
#   'question_id': 131366016},
#  {'image_id': 131366,
#   'question': 'Is this a mixed race group?',
#   'question_id': 131366017},
#  {'image_id': 131366,
#   'question': 'Are these people getting reading to go play sports?',
#   'question_id': 131366018},
#  {'image_id': 131366,
#   'question': 'Is there any females?',
#   'question_id': 131366019},
#  {'image_id': 131366,
#   'question': "How many people don't have a skateboard?",
#   'question_id': 131366020},
#  {'image_id': 131366,
#   'question': 'How many of the four main individuals are wearing baseball caps?',
#   'question_id': 131366021},
#  {'image_id': 131366,
#   'question': 'How many racquets?',
#   'question_id': 131366022},
#  {'image_id': 131366,
#   'question': 'What is the woman wearing?',
#   'question_id': 131366023},
#  {'image_id': 131366,
#   'question': 'What type of photo is this?',
#   'question_id': 131366024},
#  {'image_id': 131366, 'question': 'Is this a shop?', 'question_id': 131366025},
#  {'image_id': 131366,
#   'question': 'What sport is this?',
#   'question_id': 131366026},
#  {'image_id': 131366,
#   'question': 'What are the people holding?',
#   'question_id': 131366027},
#  {'image_id': 131366,
#   'question': 'How many legs are in the image?',
#   'question_id': 131366028},
#  {'image_id': 131366,
#   'question': 'What is the group of people holding in their hand?',
#   'question_id': 131366029},
#  {'image_id': 131366, 'question': 'Are they happy?', 'question_id': 131366030},
#  {'image_id': 131366,
#   'question': 'Is the game live or on television?',
#   'question_id': 131366031},
#  {'image_id': 497565,
#   'question': 'Are the trying to fix the train?',
#   'question_id': 497565000},
#  {'image_id': 497565,
#   'question': 'What color is the locomotive?',
#   'question_id': 497565001},
#  {'image_id': 497565,
#   'question': 'Is the train black?',
#   'question_id': 497565002},
#  {'image_id': 101431,
#   'question': 'Is this an evening scene?',
#   'question_id': 101431000},
#  {'image_id': 101431,
#   'question': 'What color is the sky?',
#   'question_id': 101431001},
#  {'image_id': 101431,
#   'question': 'Is this a desert scene?',
#   'question_id': 101431002},
#  {'image_id': 262442,
#   'question': 'How many passengers does this bus carry?',
#   'question_id': 262442000},
#  {'image_id': 262442,
#   'question': 'Is this a city street?',
#   'question_id': 262442001},
#  {'image_id': 262442,
#   'question': 'How would you call for more information about the bus?',
#   'question_id': 262442002},
#  {'image_id': 262442,
#   'question': 'Which direction is the turn lane going?',
#   'question_id': 262442003},
#  {'image_id': 21895,
#   'question': 'Is she wearing a bonnet?',
#   'question_id': 21895000},
#  {'image_id': 21895,
#   'question': "Was the woman's collar treated with starch?",
#   'question_id': 21895001},
#  {'image_id': 21895,
#   'question': 'What pattern does the woman have on?',
#   'question_id': 21895002},
#  {'image_id': 131373, 'question': 'Where is this?', 'question_id': 131373000},
#  {'image_id': 131373,
#   'question': 'Is it going to storm?',
#   'question_id': 131373001},
#  {'image_id': 131373,
#   'question': 'What kind of animal is on the beach?',
#   'question_id': 131373002},
#  {'image_id': 131373,
#   'question': 'What is running across the beach?',
#   'question_id': 131373003},
#  {'image_id': 131374,
#   'question': 'How many open umbrellas are there on the beach?',
#   'question_id': 131374000},
#  {'image_id': 131374,
#   'question': 'How many umbrellas do you see?',
#   'question_id': 131374001},
#  {'image_id': 131374,
#   'question': 'What is causing the smoke?',
#   'question_id': 131374002},
#  {'image_id': 131374,
#   'question': 'How many striped objects are in the photo?',
#   'question_id': 131374003},
#  {'image_id': 109277,
#   'question': 'What ethnicity is the man?',
#   'question_id': 109277000},
#  {'image_id': 109277,
#   'question': 'What color is the carpet in the middle of the floor?',
#   'question_id': 109277001},
#  {'image_id': 109277,
#   'question': 'Does this room have a low ceiling?',
#   'question_id': 109277002},
#  {'image_id': 131376,
#   'question': 'What color hat is this man wearing?',
#   'question_id': 131376000},
#  {'image_id': 131376,
#   'question': 'What color are the shoelaces?',
#   'question_id': 131376001},
#  {'image_id': 131376,
#   'question': 'Is the man wearing shorts or pants?',
#   'question_id': 131376002},
#  {'image_id': 131376,
#   'question': 'Is a person wearing a hooded sweatshirt?',
#   'question_id': 131376003},
#  {'image_id': 131376,
#   'question': 'Is he wearing a helmet?',
#   'question_id': 131376004},
#  {'image_id': 131376,
#   'question': "Which way is the man's hat facing?",
#   'question_id': 131376005},
#  {'image_id': 131376,
#   'question': "What color is the guy's shirt?",
#   'question_id': 131376006},
#  ...]

# %%
questionid2question = {item['question_id']: item['question'] for item in questions['questions']}

# %%
questionid2question
# Out:
# {458752000: 'What is this photo taken looking through?',
#  458752001: 'What position is this man playing?',
#  458752002: 'What color is the players shirt?',
#  458752003: 'Is this man a professional baseball player?',
#  262146000: 'What color is the snow?',
#  262146001: 'What is the person doing?',
#  262146002: 'What color is the persons headwear?',
#  524291000: "What is in the person's hand?",
#  524291001: 'Is the dog waiting?',
#  524291002: 'Is the dog looking at a tennis ball or frisbee?',
#  393221000: 'Is the sky blue?',
#  393221001: 'Is there snow on the mountains?',
#  393221002: 'What is the white streak?',
#  393223000: 'Is the window open?',
#  393223001: 'What color is the toothbrush?',
#  393223002: 'What is the child doing?',
#  393223003: 'Is she brushing?',
#  393224000: 'Is the man smiling?',
#  393224001: 'What is the business man doing in the picture?',
#  393224002: 'Does his tie pair well with his suit?',
#  393224003: 'Does the man look happy?',
#  393224004: 'Is this photo in color?',
#  393224005: 'Is the man wearing a plain tie?',
#  524297000: 'Judging from the dress, was this taken in a Latin American country?',
#  524297001: 'What colors are shown in this picture?',
#  524297002: 'Are the men on the sidewalk?',
#  524297003: 'Was this photo taken recently?',
#  393227000: 'Does the guy have a tattoo?',
#  393227001: 'What is this man riding on?',
#  393227002: "How many tattoos can be seen on this man's body?",
#  393227003: 'What color is his hat?',
#  393227004: "Is the man's visor providing his face enough protection?",
#  131084000: 'What color is the jacket?',
#  131084001: 'Is the man riding on a dirt path?',
#  131084002: 'What is the man riding on?',
#  131074000: 'What is on the pillow?',
#  131074001: 'How many pieces of furniture which are used for sleeping are featured in this picture?',
#  131074002: 'Are the walls done in a summery color?',
#  131074003: 'Is the curtain patterned?',
#  131074004: 'What is sitting on the bench?',
#  131074005: 'Are the windows the same size?',
#  393230000: 'What is this person doing?',
#  393230001: 'How many people are in this image?',
#  393230002: 'Is there a shadow of a tree in the foreground?',
#  393230003: 'What is the man doing?',
#  393230004: 'What color is the sky?',
#  393230005: 'What is the person wearing?',
#  393230006: 'Did someone forget his luggage in the snow?',
#  393230007: 'What color is his coat?',
#  393230008: 'Is it daytime?',
#  393230009: 'What is she holding?',
#  393230010: 'Is the person wearing a hat?',
#  131087000: 'What is the dog riding on?',
#  131087001: 'Is the dog wearing a collar?',
#  131087002: 'Is it a clear day?',
#  131087003: 'Is there a body of water here?',
#  131087004: 'What is in the water?',
#  131075000: 'What does the green light, on the TV, indicate?',
#  131075001: 'Is the light on?',
#  131075002: 'What room of the house is this?',
#  131075003: 'What is the size of the TV?',
#  131075004: 'Is the room messy?',
#  131075005: 'Is this a TV screen?',
#  131075006: 'How big is the TV?',
#  131075007: 'What companion object to the TV can be seen in the bottom right of the picture?',
#  131075008: 'What is the small computer on the left called?',
#  131075009: 'What is above the TV?',
#  131075010: 'What is on the display?',
#  131075011: 'Is there a laptop in the image?',
#  131075012: 'Is it a monitor or a screen projection?',
#  131075013: 'What is on the TV screen?',
#  131075014: 'What is the title of the presentation in the picture?',
#  137045000: 'What color is the bear?',
#  137045001: 'Is the animal a mammal?',
#  137045002: 'What is this?',
#  131093000: 'Are there rocks in the picture?',
#  131093001: 'Has the sheep recently been shaved?',
#  131093002: 'How many sheeps are this?',
#  131093003: 'Are there three sheep?',
#  524311000: 'What is the man playing?',
#  524311001: 'Is the man having a good time?',
#  524311002: 'What does the man have on his face?',
#  25000: 'What is in front of the giraffes?',
#  25001: 'What do these giraffes have in common?',
#  25002: 'Could this photo be from a zoo?',
#  25003: 'Are the animals eating?',
#  25004: 'Where is the giraffe?',
#  25005: 'Is there a zebra?',
#  25006: 'What is the giraffe standing behind?',
#  25007: 'Is the giraffe eating the tree?',
#  25008: 'Are both giraffes standing?',
#  25009: 'Are they at a zoo?',
#  25010: 'What is on the ground next to the giraffe on the right?',
#  25011: 'Are some of the trees dead?',
#  25012: 'Are any of the animals eating?',
#  25013: 'Is the giraffe in the shade?',
#  25014: 'Are these giraffes living free range?',
#  25015: 'How many giraffes are there?',
#  25016: 'Is there a rock near the giraffe?',
#  25017: 'How many animals are in this photo?',
#  524314000: 'Why is the man on the street?',
#  524314001: 'How is the man sitting?',
#  524314002: 'What does the word in the upper-left corner, behind the window, translate to in English?',
#  262171000: 'How many people are on the boat?',
#  262171001: 'What color are the leaves?',
#  262171002: 'What type of watercraft is that?',
#  262172000: 'Where are the two blue coolers?',
#  262172001: 'What kind of room is this?',
#  262172002: 'Are they moving?',
#  131101000: 'What color is the umbrella?',
#  131101001: 'Is this man angry?',
#  131101002: 'Which hand holds the umbrella?',
#  30000: 'Are there flowers in the vase?',
#  30001: 'What is the vase sitting on?',
#  30002: 'Is the sun to the right or left of this flower?',
#  30003: 'Are the flowers open?',
#  30004: 'What color is the vase?',
#  30005: 'Are all the flowers white?',
#  524320000: 'Is the man standing on both foot?',
#  524320001: 'Was this picture likely taken recently?',
#  524320002: "Do the gentleman's socks match his shoes and belt?",
#  240304000: 'What is the zebra eating?',
#  240304001: 'Are the zebras facing the same direction?',
#  240304002: 'What is the tree covered with?',
#  34000: 'Is this a horse?',
#  34001: 'What is the animal eating?',
#  34002: 'How old is animal?',
#  393251000: "Are they drinking wine at the child's party?",
#  393251001: 'Is the man wearing glasses?',
#  393251002: 'What is the man holding?',
#  393251003: 'What is the man cutting?',
#  262180000: 'What is the fruit?',
#  262180001: 'Is this a good dessert?',
#  262180002: 'What is the name of the type of person that would make this food?',
#  262180003: 'What type of ice cream is on the plate?',
#  524325000: 'How many people are wearing shorts in the forefront of this photo?',
#  524325001: 'Is this an indoor or outdoor photo?',
#  524325002: 'Are those kites in the air?',
#  43697000: 'Is this a hot dog?',
#  43697001: 'What color is the napkin?',
#  43697002: 'Is there ketchup on the hot dog?',
#  43697003: 'Has this hot dog been grilled?',
#  43697004: 'Have you tried a hot dog like this before?',
#  43697005: "What's missing from this hot dog?",
#  43697006: 'What is the hog dog sitting on?',
#  262184000: 'Is this a toy-sized truck?',
#  262184001: 'What is the sky full of?',
#  262184002: 'Where are the trucks?',
#  131113000: 'What is the color of the carpet?',
#  131113001: 'Is there a carpet on the floor?',
#  131113002: 'What color is the refrigerator?',
#  131113003: 'What is this device?',
#  262187000: 'Is this plane landing?',
#  262187001: 'What color is the plane?',
#  262187002: 'What shape are the windows on the side of the plane?',
#  262187003: 'Is the plane taking off?',
#  131118000: 'Are these airliners?',
#  131118001: 'How many planes are in the picture?',
#  131118002: 'Are this cargo planes?',
#  262191000: 'Is this bear a normal size?',
#  262191001: 'What is the website on the sign?',
#  262191002: 'What is the bear called?',
#  49000: 'Is there a flower arrangement on the lawn?',
#  49001: 'What color horse is closer to the camera?',
#  49002: 'Are they playing polo?',
#  524338000: 'How many trees are in this photo?',
#  524338001: 'What type of tree is the man standing next to?',
#  524338002: 'Is this man reading a cell phone screen?',
#  213863000: 'What pattern is on the pants?',
#  213863001: 'What sport is this person playing?',
#  213863002: 'What is the position of the player behind the batter called?',
#  393268000: "What color is the girl's shirt?",
#  393268001: 'What are they drinking?',
#  393268002: 'What brand of beer is visible?',
#  131126000: 'Where is Brooklyn Avenue?',
#  131126001: 'Which direction is Brooklyn Ave?',
#  131126002: 'Is there a stop sign in the picture?',
#  131127000: "What logo is on the man's shirt?",
#  131127001: 'Is the man unhappy?',
#  131127002: 'Are the men going to share the bananas?',
#  131128000: 'What color are the flowers?',
#  131128001: 'What colors are the flowers?',
#  131128002: 'How many flowers are painted on the vase?',
#  131128003: 'Do the painted flowers match the real ones?',
#  262201000: 'Where is the bird?',
#  262201001: 'Will the birds go into the water?',
#  262201002: 'What direction is the bird looking?',
#  262201003: 'Is this bird afraid of the ledge?',
#  370986000: 'What time of day is it?',
#  370986001: 'How many elephants are in the water?',
#  370986002: 'How many tails can you see in this picture?',
#  262204000: 'How many tusks are visible?',
#  262204001: 'What is this animal?',
#  262204002: 'What color is the animal?',
#  131133000: 'What color is the plane?',
#  131133001: 'What type of plane is this?',
#  131133002: 'Are the mountains high?',
#  262207000: 'What color are the seats?',
#  262207001: 'Is there a person standing in front of the television?',
#  262207002: 'Where is the mirror?',
#  262207003: 'Is there enough room under the armchairs for a cat to hide?',
#  64000: 'Who made the cock?',
#  64001: 'Are there numbers on the clock face?',
#  64002: 'Is there a big tree behind the clock?',
#  64003: 'What is in the picture?',
#  64004: 'What time is the clock showing?',
#  458763000: 'What are the vases sitting on?',
#  458763001: 'How many trees on the table?',
#  458763002: 'How many horns are in the picture?',
#  458763003: 'What color is the middle vase?',
#  458763004: 'What is the table made of?',
#  458763005: 'What kind of trees are on the table?',
#  458763006: 'Is this a wedding?',
#  567990000: 'What is the green stuff on this pizza?',
#  567990001: 'Does the crust look burnt?',
#  567990002: 'Is it thick or thin crust?',
#  567990003: 'Does this pizza have a deep dish crust?',
#  393286000: 'Is the banana freshly peeled?',
#  393286001: 'Is the banana closed?',
#  393286002: 'What is the orange thing?',
#  71000: 'Does this photo show train tracks?',
#  71001: 'Does this train work?',
#  71002: 'Is this train headed towards or from the orange building?',
#  72000: 'How many Giraffes are in this image?',
#  72001: 'What is the giraffe eating?',
#  72002: 'Are the giraffes under the trees?',
#  393228000: 'Are there 3 elephants?',
#  393228001: 'Are all of the elephants full grown?',
#  393228002: 'Are the elephants in the jungle?',
#  393290000: "What is on the woman's neck?",
#  393290001: 'Is the woman eating the pizza?',
#  393290002: 'How many stairs are there?',
#  393291000: 'Where is the sink located?',
#  393291001: 'Where is the soap?',
#  393291002: 'What color is the window frame?',
#  393291003: 'What item is folded up and sitting on the edge of the shower stall?',
#  393291004: 'What pattern is on the shower curtain?',
#  393291005: 'What are the colors of the countertop?',
#  393291006: 'Are there any reflections in this picture?',
#  393291007: 'How many windows are there?',
#  393292000: 'Is the water on?',
#  393292001: 'Is this photo outdoors?',
#  393292002: 'How many birds are in the sink?',
#  262221000: 'What is the person on the right called?',
#  262221001: "Whose logo is on the official's chair?",
#  262221002: 'How many tennis players are in the photo?',
#  78000: 'Are the clock and owl made in the same artistic fashion?',
#  78001: 'Is that owl a candle?',
#  78002: 'What time does the clock say?',
#  81000: 'Does this planes tail have 4 colors?',
#  81001: 'Is this plane landing?',
#  81002: 'Is this plane taking off?',
#  81003: 'What is the last letter over the plane?',
#  81004: 'Are these wings strong?',
#  86000: 'Is that a bicycle?',
#  86001: 'What is the number on the mailbox?',
#  86002: 'What is this person wearing on head?',
#  524375000: 'Is this a cow farm?',
#  524375001: 'What are the animals doing?',
#  524375002: 'What breed of livestock is shown?',
#  524375003: 'How many black sheep are there?',
#  524375004: 'What game would you play when you saw this as a child?',
#  524375005: 'Where is the human?',
#  524375006: 'Is this a prairie?',
#  524375007: 'Is there a village in the background?',
#  131160000: 'What color is the sign?',
#  131160001: 'Would you be able to find a mosque in this city?',
#  131160002: 'What language is the sign written in?',
#  524377000: 'How has the cheese been prepared?',
#  524377001: 'Is there ketchup?',
#  524377002: 'How many lunches is this?',
#  524377003: 'Is the hotdog well seasoned?',
#  524377004: 'What kind of food is shown?',
#  524377005: 'What is the cutting board used for in this scene?',
#  524377006: 'Of what meal is this kind of food typical?',
#  524377007: 'Is this a healthy meal?',
#  524377008: 'What kind of sauce is in the largest ramekin?',
#  524377009: 'What type of food is shown?',
#  524377010: 'What is the topping on the hot dog?',
#  524377011: 'What topping is on the hot dog?',
#  524377012: 'What is in the small container?',
#  524377013: 'What are the components of this dish?',
#  524377014: 'What kind of toppings are on the hot dogs?',
#  524377015: 'Is there a spoon in this photo?',
#  524377016: 'Is this breakfast?',
#  524377017: 'How delicious does this look?',
#  524377018: 'What two vegetables are in the white bowl?',
#  524377019: 'How many hot dogs are shown?',
#  524377020: 'What type of filling is in the dish on the bottom left?',
#  524377021: 'What color is the tray?',
#  524377022: 'How many pickle spears are there?',
#  524377023: 'What is the yellow stuff in a bowl?',
#  524377024: 'How many people are eating this hotdog?',
#  524377025: 'Is there a drink in this picture?',
#  524377026: 'What is the hot dog sitting on top of?',
#  524377027: 'How many sauces are there?',
#  524377028: 'What are the orange things?',
#  524377029: 'Are the carrots diced or cut long ways?',
#  524377030: 'Do these hot dogs look like they taste good?',
#  524377031: 'Are those tomatoes on the sandwich?',
#  524377032: 'What is in the cup?',
#  524377033: 'What is the orange root called?',
#  524377034: 'What is the blackened meat on the bread?',
#  524377035: 'What kind of meat is this?',
#  524377036: 'What is on the sandwich?',
#  524377037: 'Are the fries plain?',
#  524377038: 'Does this breakfast dish primarily carbohydrates?',
#  524377039: 'Has someone started eating?',
#  524377040: 'What animal is on the plate?',
#  524377041: 'Would this be good for dessert?',
#  524377042: 'Is there a butter plate on the table?',
#  524377043: 'Does this have lettuce?',
#  524377044: 'Does the food look good?',
#  524377045: 'Is this meat?',
#  524377046: 'What is on the hotdog?',
#  524377047: 'What two vegetables can be seen on the pizza?',
#  524377048: 'Would this typically be eaten for breakfast?',
#  524377049: 'Is that bacon from a delicatessen?',
#  524377050: 'What condiment is on the potatoes?',
#  524377051: 'How many kinds of meat products are here?',
#  524377052: 'What sauces are shown?',
#  524377053: 'What kind of potato are the fries?',
#  524377054: 'What is mainly featured?',
#  393306000: 'Is the man wearing formal clothes?',
#  393306001: 'What kind of plants are these?',
#  393306002: 'What is the pattern on the vase?',
#  393306003: 'Which hand is the man holding up?',
#  262159000: 'Is there a deodorant on the sink?',
#  262159001: 'Is there a full roll of toilet paper in the bathroom?',
#  262159002: 'How many rolls of toilet paper are on the toilet tank?',
#  262159003: 'Would someone be able to watch you change from the outside?',
#  262159004: 'What color is the bathroom?',
#  262159005: 'Does the shower have a glass door?',
#  262159006: 'What is the primary color of the bathroom?',
#  262159007: 'What color is the wall?',
#  262159008: 'Is the towel rack silver?',
#  262159009: 'Is there a shower curtain?',
#  262159010: 'What color are the bathroom walls?',
#  262159011: 'Where is the light coming from?',
#  262159012: 'Is the toilet lid down?',
#  92000: 'How many layers are in this cake?',
#  92001: 'Does this cake look like it chocolate?',
#  92002: 'How many people can eat this cake?',
#  94000: 'What is printed on the orange sign?',
#  94001: 'What is the name of the hotel?',
#  94002: 'How many vehicles are shown?',
#  94003: 'What mode of transportation is pictured?',
#  94004: 'Is this a small town?',
#  393311000: 'Will these planes be used to transport people?',
#  393311001: 'What airline is this?',
#  393311002: "The plane's stand resembles what letter?",
#  393311003: 'What type of plane is this?',
#  393311004: 'What is written on the picture?',
#  393311005: 'What shipping company is represented in the scene?',
#  393311006: 'What airline is this plane from?',
#  393311007: 'What kind of aircraft is this?',
#  393311008: 'How does the man get down from the machine?',
#  524386000: 'Is the room carpeted?',
#  524386001: 'Where is the television?',
#  524386002: 'Is there a fireplace?',
#  524386003: 'Are stains on the floor?',
#  524386004: 'How many lamps are there?',
#  524386005: 'What is the picture of on wall?',
#  524386006: 'What is on the carpet?',
#  524386007: 'How many lamps are in the room?',
#  524386008: 'Are these boys at home?',
#  524386009: 'What kind of lamp is on the floor?',
#  524386010: "Is this a 60's motif?",
#  524386011: 'How many pictures on the wall?',
#  524386012: 'Which floor lamp is not lit?',
#  524386013: 'How many TVs are on?',
#  524386014: 'What color is the sofa?',
#  524386015: 'How many pictures are on the wall?',
#  131172000: 'How many men in the picture are wearing sunglasses?',
#  131172001: 'What kind of hat is the man with the girls wearing?',
#  131172002: "What color is the man's shirt in the front of the photo?",
#  131172003: 'What are the ladies doing?',
#  393317000: 'Where is the street sign?',
#  393317001: 'Where are the women walking?',
#  393317002: 'Is the light green?',
#  393317003: 'What is written on the street?',
#  393317004: 'Is it raining?',
#  393317005: 'Urban or suburban?',
#  393317006: 'Where is the woman standing?',
#  393317007: 'How many people can be seen?',
#  393317008: 'What type of vehicle is on the left?',
#  393317009: 'Is this woman crossing a street?',
#  393317010: 'What color is the traffic signal?',
#  393317011: 'What is being held green?',
#  393317012: 'What time of day is it?',
#  393317013: 'Is this in the United States?',
#  393317014: 'How many green lights are there?',
#  131174000: 'How many lights does the plane have?',
#  131174001: 'How many planes are in this photo?',
#  131174002: 'Is there anyone in the cockpit?',
#  546151000: 'What country name is written as the highest word on the bus?',
#  546151001: 'Is the bus stopped?',
#  546151002: 'How many people are standing in this image?',
#  21826000: 'What is the skier standing on?',
#  21826001: 'How many poles is the person holding?',
#  21826002: 'What is the person doing?',
#  109000: 'Is this an ocean area?',
#  109001: 'How many bodies of water are in this scene?',
#  109002: 'How many light post is there?',
#  109003: 'Is the ground near the waterfront squishy?',
#  109004: 'What infrastructure would one drive on to go perpendicular to the water?',
#  109005: 'Is the water calm?',
#  110000: "What color is the woman's sweater?",
#  110001: 'Is this a cheese pizza?',
#  110002: 'What pizza topping is this?',
#  305853000: 'What is in the vase next to the flowers?',
#  305853001: 'Is there more than one vase on the table?',
#  305853002: 'Are these flowers real or silk?',
#  305853003: "England's Queen mother and these blooms share what syllable?",
#  113000: 'How many people are in the picture?',
#  113001: 'What color are the chairs?',
#  113002: 'What kind of celebration is this?',
#  113003: 'What emblem is on the cake?',
#  113004: 'Are they outside or in?',
#  113005: 'Is there a cake here?',
#  113006: 'Are there any pens on the table?',
#  113007: 'What are the initials on the cake?',
#  262260000: 'Why are the birds only appearing as black silhouettes?',
#  262260001: 'How many pigeons are there?',
#  262260002: 'Is this image tilted?',
#  262261000: 'What utensil is in the pan?',
#  262261001: 'What is the red vegetable in the clear dish?',
#  262261002: 'Does this image contain a pie pan?',
#  131190000: 'Is this a large house?',
#  131190001: 'Is there a fountain in front of the building?',
#  131190002: 'Is the sun shining?',
#  131190003: 'What color is the building?',
#  131190004: 'Is this a church?',
#  131190005: 'What tree is on the left?',
#  131190006: 'Are there clouds visible?',
#  131190007: 'Is this a sunny day?',
#  131190008: 'What is the material right around the clock?',
#  131190009: 'What color are the flowers?',
#  131190010: 'How many bells are there?',
#  131190011: 'How tall is this building?',
#  131190012: 'What materials are on the roof?',
#  131190013: 'How many clock faces does this building have?',
#  131190014: 'Are the hedges well-groomed?',
#  131190015: 'Does the building in the back have an elevator?',
#  131190016: 'What is in gold at the top of the building?',
#  131190017: 'Do you a phone booth?',
#  131190018: 'What color is the clock tower in this photo?',
#  131190019: 'What are on both side of the building?',
#  131190020: 'What is around the tree?',
#  131190021: 'Are the buildings tall?',
#  131190022: "How many flags are by the building's entrance?",
#  131190023: 'Is the clock between two arches?',
#  131190024: 'Are there any entrance gates at the bottom of the tower?',
#  131190025: 'Is the building a high rise?',
#  131190026: 'Is part of this tower made of wood?',
#  131190027: 'Can the tree tell time?',
#  131190028: 'How many windows are shown?',
#  131190029: 'How many windows are pictured?',
#  131190030: 'Is the emblem a sun face clock?',
#  131197000: 'What is the woman doing in this photo?',
#  131197001: 'What are the sheep standing on?',
#  131197002: 'What is the woman feeding the animal?',
#  131197003: 'How many sheep can you see?',
#  131197004: "Is the ram's fleece dirty?",
#  127000: 'Is there a travel guide on the table?',
#  127001: 'What color plate is this?',
#  127002: 'What type of silverware is on the plates?',
#  262273000: 'What color are the skis?',
#  262273001: 'Is there snow?',
#  262273002: 'What is the man holding in his left hand?',
#  262273003: 'What is the color of the zipper?',
#  262273004: 'Are the boots a solid color or patterned?',
#  262273005: 'How many people are there?',
#  262273006: 'Is it summer?',
#  262273007: "What color is the man's hat?",
#  262273008: 'How many people are in the image?',
#  524420000: "What color is the woman's shorts?",
#  524420001: 'Is the picture in color?',
#  524420002: 'Is there a dog in the photo?',
#  524420003: 'Is the dog on a leash?',
#  524420004: 'What are the people doing in the street?',
#  436929000: 'What is floating near the bird?',
#  436929001: 'Are all of the birds in flight?',
#  436929002: 'How many birds are there?',
#  436929003: 'Are there three birds in the picture?',
#  436929004: 'Is this a dog?',
#  436929005: 'Is this a winter scene?',
#  436929006: 'Is the water frozen?',
#  131208000: 'Why are there so many clothes on the bed?',
#  131208001: 'Is that a laptop on the chair?',
#  131208002: "What color is the girl's hair?",
#  284012000: 'What brand of soda is advertised?',
#  284012001: 'Is Cingular a sponsor of this field?',
#  284012002: 'What Mexican food restaurant chain is advertised?',
#  284012003: 'How is the turnout?',
#  284012004: 'How many men are playing baseball?',
#  284012005: 'What is the large sculpture next to the oversized cola bottle?',
#  284012006: "What color is the catcher's pants?",
#  138000: 'How many pots are hanging under the shelf?',
#  138001: 'What time is it?',
#  138002: 'Is this a conventional kitchen?',
#  262283000: 'What color flowers are on the top right?',
#  262283001: 'Is the area lit?',
#  262283002: 'Where was this shot at?',
#  262283003: 'Are the vases identical?',
#  524428000: 'Are these the normal size pieces of pizza?',
#  524428001: 'Could you eat all of this pizza?',
#  524428002: 'Is there broccoli on a slice of pizza?',
#  524428003: 'What color is the cloth?',
#  262285000: 'How many zebras are there?',
#  262285001: 'What continent might this be?',
#  262285002: 'Is there an animal that seems to stick out?',
#  262285003: 'Is this in a zoo?',
#  262285004: 'Is this in a desert?',
#  142000: 'What type of fruit is on the plate?',
#  142001: 'Is this a banana toast?',
#  142002: 'What color is the milk carton?',
#  131215000: 'Are the people playing a game?',
#  131215001: 'Is the TV turned on?',
#  131215002: 'Is this person watching a movie?',
#  131215003: 'What is in the blue chair?',
#  131215004: 'What type of footwear is the person wearing?',
#  144000: 'What are the animals doing?',
#  144001: 'Is one of the giraffes eating?',
#  144002: 'What type of animal is in the picture?',
#  393362000: 'Is it daytime?',
#  393362001: 'Are the kickstands down?',
#  393362002: 'Do you see any motorcycle helmets?',
#  149000: 'Is the kite high in the air?',
#  149001: 'Is the sky clear?',
#  149002: 'What color is the building?',
#  149003: 'Are the people flying kites?',
#  149004: 'Which buses are double deckers?',
#  149005: 'What kind of court is at the edge of the field?',
#  471373000: 'Can you see any fish?',
#  471373001: 'Is this man swimming?',
#  471373002: 'Is he turning?',
#  471373003: 'Does the man have short hair?',
#  471373004: 'What is this man laying on?',
#  109986000: "What color is this girl's shirt?",
#  109986001: 'What color is the girls hot dog?',
#  109986002: "What color are the girl's lips?",
#  131225000: 'What does the front of the bus say at the top?',
#  131225001: 'Is the bus featured in this picture typical?',
#  131225002: 'What color is the school bus?',
#  131225003: 'Is this the latest make and model?',
#  131225004: 'What color is the bus?',
#  131225005: 'Are there any building in the area?',
#  154000: 'Is there a fence in the background?',
#  154001: 'How many zebras can you see eating?',
#  154002: 'How many kinds of animals are in this photo?',
#  154003: "Is the zebra's tail up?",
#  154004: 'How many different types of animals are in this scene?',
#  154005: 'What direction are the animals heading?',
#  154006: 'Are they the same type of animal?',
#  154007: 'Is the zebra walking or standing still?',
#  154008: 'Are all zebras facing the same way?',
#  154009: 'How many animals are there?',
#  154010: 'Are the zebras running?',
#  154011: 'Who is in the photo?',
#  154012: 'Number of animals?',
#  262299000: 'Is he going to fall?',
#  262299001: 'What color are the stakes in the dirt?',
#  262299002: 'What color shirt is the man standing in the background wearing?',
#  393242000: 'How many arrows can be seen?',
#  393242001: 'How many stripes are at the bottom of the picture?',
#  393242002: 'Are the traffic lights facing the same direction?',
#  393375000: 'Is this cake made with fondant?',
#  393375001: 'Where is the cupcake?',
#  393375002: 'What is on the plate?',
#  393375003: 'What are the pink pieces of paper called?',
#  393379000: 'What kind of nut is shown?',
#  393379001: 'What is the green stuff?',
#  393379002: 'Is this a finger food or dish?',
#  262308000: 'What ICING IS USED ON THIS CAKE?',
#  262308001: 'Is there a fork on the plate?',
#  262308002: 'Is this black and white?',
#  262308003: 'What is the figure on the cupcake?',
#  262308004: 'What flavor is the cupcake?',
#  165000: 'What is the woman doing?',
#  165001: 'Is a military person in the picture?',
#  165002: 'Are they smiling?',
#  415089000: 'How many potted plants do you see?',
#  415089001: 'How many chairs are there?',
#  415089002: 'Is this an old building?',
#  415089003: 'What room is this?',
#  415089004: 'Is the room almost full?',
#  393384000: 'Where was this picture taken?',
#  393384001: 'How many kids in this photo?',
#  393384002: 'Are the people on a soft surface?',
#  393386000: 'How many animals?',
#  393386001: 'What color are the majority of sheep?',
#  393386002: 'Has the grass been mowed recently?',
#  131245000: 'What kind of animals are in there?',
#  131245001: 'Is this scene in America?',
#  131245002: 'What is the boy doing?',
#  137918000: 'Are all the laptops on?',
#  137918001: 'How many laptops are on the coffee table?',
#  137918002: 'Where is the laptop?',
#  393394000: 'What animal is on the walls?',
#  393394001: 'Is this a hotel room?',
#  393394002: 'Where are the two upside down glasses?',
#  393394003: 'Is this a hotel?',
#  438196000: 'Is an elephant walking down the street?',
#  438196001: 'Is the guy in the yellow shirt wearing a tie?',
#  438196002: 'How many people are in the picture?',
#  393396000: 'Is this a church?',
#  393396001: 'Sunny or overcast?',
#  393396002: 'Is there snow in the picture?',
#  393396003: 'What is the color of the roof shingles?',
#  393396004: 'What symbol sits atop the tower?',
#  393396005: 'Is there a clock on the church tower?',
#  393396006: 'Is there a clock?',
#  524470000: 'Is this person wearing a backpack?',
#  524470001: 'Is there a street light in the photo?',
#  524470002: 'Is the sun up?',
#  524471000: 'What is the grate for?',
#  524471001: 'Is the oven on?',
#  524471002: 'Is there a window in this scene?',
#  524471003: 'What kind of siding is on this house?',
#  524471004: 'Is this toast done?',
#  524471005: 'How many knobs are there?',
#  524471006: 'Is the microwave on?',
#  524471007: 'Is the toaster on?',
#  262329000: 'What color are the flowers?',
#  262329001: 'What time is it?',
#  262329002: 'What is the brown object with a clock on it?',
#  393403000: 'How many buses are there?',
#  393403001: 'Is this a one way street?',
#  393403002: 'Are there people boarding the bus?',
#  393403003: 'What color is the bus?',
#  393403004: 'What number bus is this?',
#  393403005: 'Where is the open door?',
#  393403006: 'Is there a hardware store in the area?',
#  393403007: 'How many decks does this bus have?',
#  524476000: 'Are the drying the animal with a blow dryer?',
#  524476001: 'What color are the girls earrings?',
#  524476002: 'What is the woman holding?',
#  283700000: 'What kind of vehicle is the yellow one?',
#  283700001: 'How many windows?',
#  283700002: 'Is this a hotel?',
#  262336000: "Can you see the man's shadow?",
#  262336001: 'Is this lacrosse?',
#  262336002: 'The color of the court is green?',
#  194000: 'What color is the plate?',
#  194001: 'Who is going to eat this pizza?',
#  194002: 'Is this pizza nutritious enough to eat for a full dinner?',
#  257513000: 'What shape is at the bottom of the pole?',
#  257513001: 'Are both beds made?',
#  257513002: 'Is there a ladder in the picture?',
#  257513003: 'How many steps does it take to get to the top?',
#  257513004: 'What type of bed is in the picture?',
#  393412000: 'Is this vehicle parked in a residential driveway?',
#  393412001: 'Is the color of the car very common for vehicles?',
#  393412002: 'What color is the car?',
#  524486000: 'What is he cooking?',
#  524486001: 'Where are the buns?',
#  524486002: 'Why is the man cooking so many hot dogs?',
#  458785000: 'Is this a new or ancient clock?',
#  458785001: 'What time does the clock read?',
#  458785002: 'Are all the people looking at the same thing?',
#  201000: 'Do these ski boards have personality?',
#  201001: 'How many ski boards are in the picture?',
#  201002: 'What mountain was this taken at?',
#  393418000: 'What is the black thing he is wearing?',
#  393418001: 'What kind of room is this?',
#  393418002: 'What is the man doing in the picture?',
#  393419000: 'What is the cartoon man presenting to the cartoon woman?',
#  393419001: 'What color is the sign?',
#  393419002: 'What does the sign with the white arrow say?',
#  393419003: 'Which way can you not turn?',
#  393419004: 'What is above the "No Left Turn" sign?',
#  131277000: 'Is the woman wearing a dress?',
#  131277001: 'Are they playing a game?',
#  131277002: 'Will the bent person fall forward?',
#  131277003: 'Is there a man and a woman?',
#  131277004: 'Is this photo to blurry?',
#  393422000: 'Would you get a ticket if you disobeyed this sign?',
#  393422001: 'Is the red stop sign on a wooden pole?',
#  393422002: 'What is the sign says?',
#  393422003: 'Can you see the sun in the picture?',
#  131279000: 'Which baby is still an infant?',
#  131279001: 'How many blue stripes are on the babies shirt?',
#  131279002: 'Are they twins?',
#  131279003: 'Is one of the children a boy?',
#  131279004: 'How many babies are in this photo?',
#  131279005: 'Are these teenagers?',
#  131279006: 'Are both of the children smiling?',
#  131279007: "What color is the girl's brush?",
#  131279008: 'What gender are both of the children likely to be?',
#  131279009: 'What color is the comb?',
#  131279010: 'Is this child wearing socks?',
#  131279011: "What is the one girl doing to the other girl's hair?",
#  448671000: 'Where is the table lamp?',
#  448671001: "Something new to wear with a men's shirt?",
#  448671002: "Is the man's shirt a solid color?",
#  393428000: 'What is this person holding?',
#  393428001: 'What color is the table?',
#  393428002: 'Where is the cup?',
#  393428003: 'How much did they pay for the hot dogs?',
#  554301000: "What is in the man's hand?",
#  554301001: 'How many balls are on the ground?',
#  554301002: 'Is this man tan?',
#  262359000: 'The tablecloths are white?',
#  262359001: 'What silverware is on the table?',
#  262359002: 'Where do you think all these are located?',
#  262359003: 'What color is the knife handle?',
#  262359004: 'Are the pictures colorful?',
#  262359005: 'Do you a mirror in the background?',
#  262359006: 'How many glasses are there?',
#  262359007: 'Is there food on the table?',
#  262359008: 'Where is the room?',
#  393432000: 'What type of animal is it?',
#  393432001: 'Where is the cat?',
#  393432002: 'Is there a pillow present in the picture?',
#  393432003: 'What color eyes does the cat have?',
#  36000: 'Is she wearing a bathing suit?',
#  36001: 'What color is the umbrella?',
#  36002: 'Why is the girl holding an umbrella?',
#  524508000: 'How many horses are on the picture?',
#  524508001: 'How many horses are in the picture?',
#  524508002: 'Are they surrounded by trees?',
#  524508003: 'Is there a puddle of water on the dirt?',
#  474858000: 'What is the man standing on?',
#  474858001: 'Are these men on a boat?',
#  474858002: "What color is the man's skin?",
#  474858003: 'What are these men standing in front of?',
#  474858004: 'What is the temperature outside?',
#  474858005: 'Are the boys happy?',
#  474858006: 'Is the man in the forefront trying to get signal on a cell phone?',
#  474858007: 'What is this person standing on?',
#  474858008: 'Were people moving when this picture was taken?',
#  474858009: 'What is lying on the ground?',
#  474858010: 'What is flying in the air?',
#  474858011: 'What brand of shoes is the skateboarder wearing?',
#  474858012: 'Was this photo taken recently?',
#  474858013: 'Is this  a beach?',
#  474858014: 'Is the guy making a performance?',
#  474858015: 'Is he doing a trick?',
#  474858016: 'Is the man in the foreground barefooted?',
#  474858017: 'Is this busy metropolis?',
#  474858018: 'What is the man on a skateboard?',
#  474858019: 'Which man is controlling the kite?',
#  474858020: 'Are there waves in the picture?',
#  474858021: 'What type of clouds are visible in this photo?',
#  474858022: 'What is the man doing?',
#  474858023: 'Is the person on the right male or female?',
#  474858024: 'What object is painted on the surfboard?',
#  474858025: 'What color is the shirt of the man standing?',
#  474858026: 'What color is the board?',
#  393438000: 'How many kids?',
#  393438001: 'What colors are in the kite?',
#  393438002: "Did the man just steal the boy's kite?",
#  165859000: "What color is the train's bumper?",
#  165859001: 'Is this a steam engine train?',
#  165859002: 'What does the train ride along?',
#  39288000: 'What is turned on?',
#  39288001: 'What is the name of the yellow fruit pictured?',
#  39288002: 'Why would someone not like the fruit at the front?',
#  393442000: 'What color dresses are the women wearing?',
#  393442001: 'Are the umbrellas wet?',
#  393442002: 'How many black umbrellas?',
#  131299000: 'Which vehicle is the smallest?',
#  131299001: 'Is there snow on the ground?',
#  131299002: 'How many skis are on the ground?',
#  131300000: 'What kind of pizza is this?',
#  131300001: 'Does this oven look new?',
#  131300002: 'Does the oven have a digital buttons?',
#  131300003: 'Is this oven greasy?',
#  131300004: 'Is the pizza on a baking tray?',
#  393445000: 'Do you like chocolate cake?',
#  393445001: 'What color is the plate?',
#  393445002: 'What is this cake made with?',
#  524518000: 'What shape are the plates?',
#  524518001: 'Are there any water glasses on the table?',
#  524518002: 'What indicates that this is for a party?',
#  524518003: 'Are there tomatoes on the pizza?',
#  524518004: 'What two utensils are next to the plate?',
#  524518005: 'Are there any people in the picture?',
#  524520000: 'Can they go?',
#  524520001: 'Are the cars parked?',
#  524520002: 'Why is the top light on?',
#  524520003: 'How lucky is it that no one was walking on the sidewalk at that time?',
#  524520004: 'What traffic light is on?',
#  524522000: 'Are all the players wearing black shirts?',
#  524522001: 'What number does the battery have on his shirt?',
#  524522002: 'What team is the batter from?',
#  524522003: 'How many water jugs are visible?',
#  524525000: 'What color is the picket fence?',
#  524525001: 'How many trains are there?',
#  524525002: 'Is one of the trains going through a tunnel?',
#  131312000: 'Who is the woman the picture on wall?',
#  131312001: 'Is the door open?',
#  131312002: 'Is the man on TV wearing a tie?',
#  131312003: 'What objects are directly above the TV set?',
#  131315000: 'Is everyone wearing glasses?',
#  131315001: "What print is this woman's dress?",
#  131315002: 'Are both people of the same ethnic background?',
#  262389000: 'The man is wearing a helmet?',
#  262389001: 'What is on the handlebars?',
#  262389002: "What bird is on the man's bike?",
#  247000: 'What color is this airplane?',
#  247001: 'Who is the pilot?',
#  247002: "Is this a government official's plane?",
#  393464000: 'Are the kids sitting?',
#  393464001: 'How many kids are there?',
#  393464002: 'Are these children playing a game?',
#  262393000: 'How many rocks?',
#  262393001: 'What is the fence made of?',
#  262393002: 'The zebras are in a field?',
#  262393003: 'How many zebras are there?',
#  250000: 'How many floors do you think the highest building has?',
#  250001: 'Have you ever been to this intersection?',
#  250002: 'What is the name of the street that starts with a color?',
#  131323000: 'Are some of the trees dead?',
#  131323001: 'Are the rocks for the giraffe to sit on?',
#  131323002: 'How can you tell the giraffe is in captivity?',
#  262399000: 'What is the name of the store behind the lady?',
#  262399001: 'What does the lady have in her mouth?',
#  262399002: "What color is the woman's shirt?",
#  131330000: 'Does someone have a green thumb?',
#  131330001: 'Is the seedling a hybrid?',
#  131330002: 'What are the popsicle sticks used for?',
#  524547000: 'Why is the man in mid-air?',
#  524547001: 'Is there a tent in the snow?',
#  524547002: 'What is the structure in the background?',
#  260000: 'What color is the lighted sign?',
#  260001: 'Is this terminal safe at night?',
#  260002: 'Is the woman by herself?',
#  524551000: 'Is it a clear day?',
#  524551001: 'What is this person doing?',
#  524551002: 'What are these people doing?',
#  524551003: 'What is the white structure behind the ramp?',
#  393480000: 'Is this person prone on his back or on his knees?',
#  393480001: 'Is the skier on the ground?',
#  393480002: 'Is the subject of the photo facing downhill?',
#  393480003: 'What kind of trees are in this photo?',
#  393480004: 'What is on the ground?',
#  131339000: 'What color is the surfboard?',
#  131339001: 'What is the man wearing?',
#  131339002: 'Is this man attached to his surfboard?',
#  131339003: 'Is this man riding a surfboard?',
#  131339004: 'Is he wearing the right type of suit?',
#  131339005: 'Is the man riding a white board?',
#  131339006: 'How many people are surfing?',
#  131339007: 'Is the woman surfing?',
#  131339008: 'What kind of suit is he wearing?',
#  524557000: 'What sport are they playing?',
#  524557001: 'Color is the goaltenders shirt?',
#  524557002: 'Where is number 8?',
#  524557003: 'How many kids are wearing black and white?',
#  524557004: 'Is the boy in the middle being attacked?',
#  524557005: 'Does the boy have his head stuck in the net?',
#  131342000: 'How many men are wearing hats?',
#  131342001: 'Does the guy on the right look happy?',
#  131342002: 'Are they coworkers or best friends?',
#  131342003: 'What is in the glass in the lower right?',
#  131342004: 'The wall is made out of?',
#  262415000: 'What does the sign in the background say?',
#  262415001: 'What color is the bus in the mirror?',
#  262415002: 'What is behind the mirror?',
#  262415003: 'What kind of passenger does the bus carry?',
#  393488000: 'How healthy does this meal look?',
#  393488001: 'Are there multiple vegetables on the plate?',
#  393488002: 'What meat is used in the main dish?',
#  393488003: 'Is there meat on the plate?',
#  393489000: 'What is the man reaching for?',
#  393489001: 'Is this a brand new phone?',
#  393489002: 'What kind of id is that?',
#  393489003: 'What color is the phone?',
#  393489004: 'Does this phone fold closed?',
#  393489005: 'What language is the text on the sign?',
#  393489006: 'How many holes are on the phone case?',
#  393489007: 'What is the man holding?',
#  393489008: 'What does this phone case look like?',
#  393489009: 'What is the brand of the phone?',
#  393489010: 'Is the phone broken?',
#  393489011: 'What does this controller go with?',
#  393489012: 'Is the phone light on?',
#  393489013: 'Which hand is the person holding the phone in?',
#  393489014: 'Is the display on?',
#  393489015: 'Is the person using skype?',
#  393489016: 'How many phones do you see?',
#  393489017: 'Is the phone on?',
#  393489018: 'Is the background clear?',
#  393489019: 'What brand is the phone?',
#  393489020: 'What kind of phone is this?',
#  393489021: 'What is the person holding in their hand?',
#  393489022: 'What is the person holding?',
#  336077000: 'Is this an inside stadium?',
#  336077001: 'Is the stadium crowded?',
#  336077002: 'Is the stadium full?',
#  336077003: 'Is there a baseball player holding a bat?',
#  546179000: 'Is this bathroom all white?',
#  546179001: 'Has the bathroom been renovated recently?',
#  546179002: "What's on the other side of the shower curtain?",
#  546179003: 'Are there towels on the ground?',
#  546179004: 'What color is the shower curtain?',
#  546179005: 'Does this look clean?',
#  546179006: 'Where is the shower located?',
#  546179007: 'Is the shower curtain open?',
#  9000: 'How many cookies can be seen?',
#  9001: 'What color are the dishes?',
#  9002: 'What is the green stuff?',
#  393493000: 'Does this bike have training wheels?',
#  393493001: 'How many girls are visible?',
#  393493002: 'Is the picnic table red?',
#  131351000: 'Is this a clean room?',
#  131351001: 'How many colors are in the tile?',
#  131351002: 'What is the floor made of?',
#  131351003: 'Is this bathroom clean?',
#  131351004: 'Is the room clean?',
#  131351005: 'What color is the water in the bathtub?',
#  131351006: 'Is there a mirror in the bathroom?',
#  131351007: 'What is the ratio of white tiles to blue?',
#  131351008: 'Is there a green plant in this room?',
#  131351009: 'What power tool is present?',
#  131351010: 'Is this room clean?',
#  131352000: 'What fruit is present?',
#  131352001: 'What color are these mattresses?',
#  131352002: 'Which room is this?',
#  524572000: 'Where is the cat sitting?',
#  524572001: 'What do you think the cat is looking at?',
#  524572002: 'Is the cat trying to catch a bird?',
#  112497000: 'What utensil is sitting next to the food?',
#  112497001: 'What is in the jug?',
#  112497002: 'What is the name of this crusted food?',
#  393503000: 'What color are the items on the truck?',
#  393503001: 'Is the writing in French?',
#  393503002: 'Is this a traveling circus?',
#  393503003: 'What animal is on the flatbed?',
#  393508000: 'What room of the house is this?',
#  393508001: 'What is the floor made out of?',
#  393508002: 'What do you use the stove for?',
#  414639000: 'What is the batter wearing on his ankles?',
#  414639001: 'Are there long lenses?',
#  414639002: 'What is the crouching man in the mask called?',
#  131366000: 'How many people are standing next to each other?',
#  131366001: 'What are the two women carrying?',
#  131366002: 'What are these people holding?',
#  131366003: 'How many rackets?',
#  131366004: 'How many people are in this photo?',
#  131366005: 'What is the woman wearing on her neck?',
#  131366006: 'Is everyone wearing long sleeves?',
#  131366007: 'What sports are they playing?',
#  131366008: 'What is the approximate time period of this photo?',
#  131366009: 'How many girls are in the picture?',
#  131366010: 'Which two are actually playing?',
#  131366011: 'Are the woman wearing short dresses?',
#  131366012: 'Is the lady smiling?',
#  131366013: 'Do they play for Red Sox?',
#  131366014: 'What are the ladies doing?',
#  131366015: 'What three letter word, best describes the liquid container on the ground between the two people?',
#  131366016: 'What does the wall say on the far left?',
#  131366017: 'Is this a mixed race group?',
#  131366018: 'Are these people getting reading to go play sports?',
#  131366019: 'Is there any females?',
#  131366020: "How many people don't have a skateboard?",
#  131366021: 'How many of the four main individuals are wearing baseball caps?',
#  131366022: 'How many racquets?',
#  131366023: 'What is the woman wearing?',
#  131366024: 'What type of photo is this?',
#  131366025: 'Is this a shop?',
#  131366026: 'What sport is this?',
#  131366027: 'What are the people holding?',
#  131366028: 'How many legs are in the image?',
#  131366029: 'What is the group of people holding in their hand?',
#  131366030: 'Are they happy?',
#  131366031: 'Is the game live or on television?',
#  497565000: 'Are the trying to fix the train?',
#  497565001: 'What color is the locomotive?',
#  497565002: 'Is the train black?',
#  101431000: 'Is this an evening scene?',
#  101431001: 'What color is the sky?',
#  101431002: 'Is this a desert scene?',
#  262442000: 'How many passengers does this bus carry?',
#  262442001: 'Is this a city street?',
#  262442002: 'How would you call for more information about the bus?',
#  262442003: 'Which direction is the turn lane going?',
#  21895000: 'Is she wearing a bonnet?',
#  21895001: "Was the woman's collar treated with starch?",
#  21895002: 'What pattern does the woman have on?',
#  131373000: 'Where is this?',
#  131373001: 'Is it going to storm?',
#  131373002: 'What kind of animal is on the beach?',
#  131373003: 'What is running across the beach?',
#  131374000: 'How many open umbrellas are there on the beach?',
#  131374001: 'How many umbrellas do you see?',
#  131374002: 'What is causing the smoke?',
#  131374003: 'How many striped objects are in the photo?',
#  109277000: 'What ethnicity is the man?',
#  109277001: 'What color is the carpet in the middle of the floor?',
#  109277002: 'Does this room have a low ceiling?',
#  131376000: 'What color hat is this man wearing?',
#  131376001: 'What color are the shoelaces?',
#  131376002: 'Is the man wearing shorts or pants?',
#  131376003: 'Is a person wearing a hooded sweatshirt?',
#  131376004: 'Is he wearing a helmet?',
#  131376005: "Which way is the man's hat facing?",
#  131376006: "What color is the guy's shirt?",
#  ...}

# %%
annotations['annotations'][0]
# Out:
# {'question_type': 'what is this',
#  'multiple_choice_answer': 'net',
#  'answers': [{'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3},
#   {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6},
#   {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9},
#   {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}],
#  'image_id': 458752,
#  'answer_type': 'other',
#  'question_id': 458752000}

# %%
def get_most_probable_answers(answers):
    answers_count = dict()
    for answer in answers:
        answers_count[answer['answer']] = answers_count.get(answer['answer'], 0) + 1
    max_answer = max(answers_count, key = answers_count.get)
    return max_answer

# %%
def build_dataset(questions, annotations):
    questionid2question = {item['question_id']: item['question'] for item in questions['questions']}
    questions = questions['questions'] # image_id, question, question_id
    annotations = annotations['annotations'] # image_id, question_id, answers
    question = [questionid2question[item['question_id']] for item in annotations]
    image_id = [item['image_id'] for item in annotations]
    answer = [get_most_probable_answers(item['answers']) for item in annotations]
    df = pd.DataFrame(list(zip(image_id, question, answer)), columns =['image_id', 'question', 'answer'])
    return df

# %%
df = build_dataset(questions, annotations)

# %%
df.head()
# Out:
#    image_id                                     question   answer
# 0    458752    What is this photo taken looking through?      net
# 1    458752           What position is this man playing?  pitcher
# 2    458752             What color is the players shirt?   orange
# 3    458752  Is this man a professional baseball player?      yes
# 4    262146                      What color is the snow?    white

# %%
all_possible_answers = df['answer'].unique()
len(all_possible_answers)
# Out:
# 22706

# %%
threshold_instance_per_class = 1000
threshold_num_classes = 20
sample_size = 1000

def choose_classes_strategy(filterd_answers_freq, threshold_num_classes=None, strategy=None):
    strategy = strategy.lower()
    assert strategy in ['max', 'min', 'random', None]

    if strategy is None:
        # choose all classes
        chosen_classes = filterd_answers_freq.keys()
    elif strategy == 'min':
        # choose classes which have minimum number of frequencies
        assert(threshold_num_classes is not None)
        chosen_classes = sorted(filterd_answers_freq, key=lambda x:filterd_answers_freq[x])[0:threshold_num_classes]
    elif strategy == 'max':
        # choose classes which have maximum number of frequencies
        assert(threshold_num_classes is not None)
        chosen_classes = sorted(filterd_answers_freq, key=lambda x:filterd_answers_freq[x], reverse=True)[0:threshold_num_classes]
    elif strategy == 'random':
        # choose classes randomly
        assert(threshold_num_classes is not None)
        chosen_classes = random.sample(list(filterd_answers_freq.keys()), threshold_num_classes)

    return chosen_classes


def filter_dataframe(df, chosen_classes, sample_size):
    sampled_rows = []
    # TODO 1: sampling from chosen classes

    return pd.concat(sampled_rows)



def get_final_df(df, threshold_instance_per_class=None, threshold_num_classes=None, sample_size=None):
    ans_freq = df['answer'].value_counts()
    filterd_answers_freq = ans_freq[ans_freq > threshold_instance_per_class]
    chosen_classes = choose_classes_strategy(filterd_answers_freq, threshold_num_classes, strategy='random')
    filtered_df = filter_dataframe(df, chosen_classes, sample_size)
    return filtered_df

# %%
new_df = get_final_df(df, threshold_instance_per_class, threshold_num_classes, sample_size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-ffb4276d4f47> in <cell line: 1>()
# ----> 1 new_df = get_final_df(df, threshold_instance_per_class, threshold_num_classes, sample_size)
#
# <ipython-input-17-afee37495080> in get_final_df(df, threshold_instance_per_class, threshold_num_classes, sample_size)
#      38     filterd_answers_freq = ans_freq[ans_freq > threshold_instance_per_class]
#      39     chosen_classes = choose_classes_strategy(filterd_answers_freq, threshold_num_classes, strategy='random')
# ---> 40     filtered_df = filter_dataframe(df, chosen_classes, sample_size)
#      41     return filtered_df
#      42
#
# <ipython-input-17-afee37495080> in filter_dataframe(df, chosen_classes, sample_size)
#      30     # TODO 1: sampling from chosen classes
#      31
# ---> 32     return pd.concat(sampled_rows)
#      33
#      34
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     370         copy = False
#     371
# --> 372     op = _Concatenator(
#     373         objs,
#     374         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     427
#     428         if len(objs) == 0:
# --> 429             raise ValueError("No objects to concatenate")
#     430
#     431         if keys is None:
#
# ValueError: No objects to concatenate

# %%
new_df

# %%
new_df.to_csv("new_df.csv")

# %%
new_df = pd.read_csv("new_df.csv", index_col = 0)

# %%
# TODO 2: make a report from dataset
# plot
# number of classes and which classes
# number of samples from each class

# %%
def train_val_test_split(df, train_portion = 0.9, val_portion = 0.05, test_portion = 0.05):
    df_train, df_val, df_test, _ = np.split(df.sample(frac=1, random_state=42), [int(train_portion * len(df)), int((train_portion + val_portion) * len(df)), int((train_portion + val_portion + test_portion) * len(df))])
    # TODO 3: Reset train, val , test dataframe index

    return df_train, df_val, df_test

# %%
df_train, df_val, df_test = train_val_test_split(new_df)
max_question_len = max(new_df['question'].apply(lambda x: len(x)))
MAX_LEN = 100

# %%
len(new_df), len(df_train), len(df_val), len(df_test)

# %%
max_question_len

# %%
def get_tokenizer_output(tokenizer, text, attr):
    return np.array(tokenizer(text, padding='max_length', max_length = MAX_LEN, truncation=True, return_tensors="pt")[attr])

# %%
train_transform = transforms.Compose([
            transforms.Resize((112,112)),
            transforms.ToTensor(),
        ])

val_transform = transforms.Compose([
            transforms.Resize((112,112)),
            transforms.ToTensor(),
        ])

test_transform = transforms.Compose([
            transforms.Resize((112,112)),
            transforms.ToTensor(),
        ])

class SimpleVQADataset(Dataset):
    def __init__(self, df, tokenizer, classes, transform):
        super(SimpleVQADataset, self).__init__()
        self.df = df
        self.tokenizer = tokenizer
        self.labels = []
        self.label2idx = {c:i for i, c in enumerate(classes)}
        self.idx2label = {i:c for i, c in enumerate(classes)}
        self.mapping = self.cunstruct_mapping_dict()
        self.encodings = {}
        self.encodings['input_ids']=[]
        self.encodings['attention_mask']=[]
        self.transform = transform

        for index, row in df.iterrows():
            self.encodings['input_ids'].append(get_tokenizer_output(self.tokenizer, row['question'], 'input_ids'))
            self.encodings['attention_mask'].append(get_tokenizer_output(self.tokenizer, row['question'], 'attention_mask'))
            self.labels.append(self.label2idx[self.mapping[row['answer'].lower()]])
        self.encodings['input_ids'] = np.array(self.encodings['input_ids'])
        self.encodings['attention_mask'] = np.array(self.encodings['attention_mask'])

        self.img_ids = df['image_id']
        self.labels = np.array(self.labels).reshape(-1, 1)


    def __len__(self):
        return len(self.labels)


    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        image_id = self.img_ids[idx]
        item['image_id'] = image_id
        filename = 'COCO_train2014_'+ str(image_id).zfill(12) + '.jpg'
        trg = os.path.join('./images', filename)
        img = self.transform(Image.open(trg).convert('RGB'))
        item['image'] = img

        return item

    def cunstruct_mapping_dict(self, ):
        map_dict = {}
        for item in self.idx2label.values():
            map_dict[item.lower()] = item
        return map_dict

# %%
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# %%
classes = new_df['answer'].unique()
classes

# %%
train_dataset = SimpleVQADataset(df_train, tokenizer, classes, train_transform)
val_dataset = SimpleVQADataset(df_val, tokenizer, classes, val_transform)
test_dataset = SimpleVQADataset(df_test, tokenizer, classes, test_transform)

print("ٔNumber of samples in train split", len(train_dataset))
print("Number of samples in val split", len(val_dataset))
print("Number of samples in test split", len(test_dataset))

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
import os
import urllib.request
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import matplotlib.pyplot as plt

target_folder = './'
subfolder_name = 'images'
subfolder_path = os.path.join(target_folder, subfolder_name)

if not os.path.exists(subfolder_path):
    os.makedirs(subfolder_path)

unique_image_ids = new_df['image_id'].unique()

def download_image(img_id):
    filename = 'COCO_train2014_'+ str(img_id).zfill(12) + '.jpg'
    src = os.path.join('https://vqa_mscoco_images.s3.amazonaws.com/train2014/', filename)
    trg = os.path.join(subfolder_path, filename)
    if not os.path.exists(trg):
        urllib.request.urlretrieve(src, trg)

# Using ThreadPoolExecutor to concurrently download images
with ThreadPoolExecutor() as executor:
    list(tqdm(executor.map(download_image, unique_image_ids), total=len(unique_image_ids)))

# %% [markdown]
# # VQA Model

# %%
# Step 3: Define the VQA model
class VQAModel(nn.Module):
    def __init__(self, image_feature_extractor, question_feature_extractor, hidden_dim, num_classes):
        super(VQAModel, self).__init__()
        # Image feature extractor (e.g., ResNet50)
        self.image_feature_extractor = image_feature_extractor

        # Question feature extractor (e.g., LSTM)
        self.question_feature_extractor = question_feature_extractor

        # Combined image and question classifier
        self.classifier = nn.Sequential(
            # Define the layers that combine image and question features
            # TODO 5: Linear(hidden_dim, hidden_dim), Dropout 0.2, ReLU, Linear

        )

    def forward(self, image, input_ids, attention_mask):
        # Process the image through the image_features
        image_embedding = self.image_feature_extractor(image).squeeze((2, 3))

        # Process the question through the question_features
        question_embedding = self.question_feature_extractor(input_ids=input_ids,attention_mask=attention_mask).last_hidden_state.mean(dim=1)

        # Combine the image and question features
        # TODO 6: concatenate image embedding and question embedding
        combined_embedding = None

        # Make a prediction using the classifier
        output = self.classifier(combined_embedding)
        return output

# %%
# Step 4: Train the model
def train_model(model, train_loader, criterion, optimizer, num_epochs):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0.0
        total_correct = 0
        total_samples = 0
        for train_batch in tqdm(train_loader):
            images = train_batch['image'].squeeze(1).to(device)
            input_ids = train_batch['input_ids'].squeeze(1).to(device).to(device)
            attention_mask = train_batch['attention_mask'].squeeze(1).to(device)
            train_label = train_batch['labels'].squeeze(1).to(device)

            # Forward pass
            outputs = model(images, input_ids, attention_mask)
            _, preds = torch.max(outputs, dim=1)

            # Compute the loss
            loss = criterion(outputs, train_label)

            # Backpropagation
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            total_correct += (preds == train_label).sum().item()
            total_samples += train_label.size(0)

            # Clear the gradients
            optimizer.zero_grad()

        # Print the loss for this epoch
        print(f"Train, Epoch {epoch + 1} : Loss = {total_loss / len(train_dataloader):.4f}, Accuracy = {total_correct / total_samples:.4f}")

# Step 5: Evaluate the model
def evaluate_model(model, val_loader, criterion, optimizer):
    model.eval()
    correct = 0
    total = 0
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for val_batch in tqdm(val_loader):
            images = val_batch['image'].squeeze(1).to(device)
            input_ids = val_batch['input_ids'].squeeze(1).to(device).to(device)
            attention_mask = val_batch['attention_mask'].squeeze(1).to(device)
            val_label = val_batch['labels'].squeeze(1).to(device)

            # Forward pass
            outputs = model(images, input_ids, attention_mask)

            # Get the predicted answers
            _, preds = torch.max(outputs, dim=1)

            # Update total and correct predictions
            total_correct += (preds == val_label).sum().item()
            total_samples += val_label.size(0)

    print(f"Evaluation : Accuracy = {total_correct / total_samples:.4f}")

# %%
classes

# %%
if __name__ == "__main__":
    # Set device (CPU or GPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    hidden_dim = 512 + 768    # Replace with the desired hidden dimension

    # TODO 7: load resnet18 pretrained
    model_ft = None

    # TODO 8: use all layers except the last one which is for classification
    image_feature_extractor = None


    question_feature_extractor = DistilBertModel.from_pretrained('distilbert-base-uncased')
    num_classes = len(classes)

    model = VQAModel(image_feature_extractor, question_feature_extractor, hidden_dim, num_classes).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    num_epochs = 10

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        total_correct = 0
        total_samples = 0
        for train_batch in tqdm(train_dataloader):
            images = train_batch['image'].squeeze(1).to(device)
            input_ids = train_batch['input_ids'].squeeze(1).to(device).to(device)
            attention_mask = train_batch['attention_mask'].squeeze(1).to(device)
            train_label = train_batch['labels'].squeeze(1).to(device)

            # Forward pass
            outputs = model(images, input_ids, attention_mask)
            _, preds = torch.max(outputs, dim=1)

            # Compute the loss
            loss = criterion(outputs, train_label)

            # Backpropagation
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            total_correct += (preds == train_label).sum().item()
            total_samples += train_label.size(0)

            # Clear the gradients
            optimizer.zero_grad()
        print(f"Train, Epoch {epoch + 1} : Loss = {total_loss / len(train_dataloader):.4f}, Accuracy = {total_correct / total_samples:.4f}")


        model.eval()
        correct = 0
        total = 0
        total_loss = 0.0
        total_correct = 0
        total_samples = 0

        # with torch.no_grad():
        for val_batch in tqdm(val_dataloader):
            images = val_batch['image'].squeeze(1).to(device)
            input_ids = val_batch['input_ids'].squeeze(1).to(device).to(device)
            attention_mask = val_batch['attention_mask'].squeeze(1).to(device)
            val_label = val_batch['labels'].squeeze(1).to(device)

            # Forward pass
            outputs = model(images, input_ids, attention_mask)

            # Get the predicted answers
            _, preds = torch.max(outputs, dim=1)
            loss = criterion(outputs, val_label)

            # Update total and correct predictions
            total_loss += loss.item()
            total_correct += (preds == val_label).sum().item()
            total_samples += val_label.size(0)

        print(f"Evaluation, Epoch {epoch + 1} : Loss = {total_loss / len(val_dataloader):.4f}, Accuracy = {total_correct / total_samples:.4f}")

# %%
evaluate_model(model, test_dataloader, criterion, optimizer)
